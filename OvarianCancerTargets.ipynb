# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import sklearn.decomposition
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import auc, accuracy_score, confusion_matrix, roc_curve, precision_score, recall_score, f1_score
import tensorflow as tf
from tensorflow import keras
import os

# %%
MergedData0 = pd.read_csv('Data.csv', index_col=0);
MergedData1 = MergedData0.iloc[:, :-1]
y = pd.read_csv("ovarian_training_genes_set.csv", index_col='gene')
y.rename_axis("DepMap_ID")
y = y == 'positive'
data = MergedData1.merge(y, how='inner', left_index=True, right_index=True)
Data = data.iloc[:, :-1]
y = data.iloc[:, -1]
display(Data)
display(y)
# Out:
#          ACH-000001_x  ACH-000004_x  ACH-000005_x  ACH-000007_x  ACH-000009_x  \
# AAK1         0.238209      0.011015      0.031624      0.073432      0.105474
# ABCC2        0.134062      0.023329      0.006485      0.022153      0.033180
# ABCG1        0.046197      0.347395      0.456456      0.099056      0.136288
# ABHD17C      0.013039      0.034789      0.036946      0.013561      0.007397
# ABHD17C      0.013039      0.034789      0.036946      0.013561      0.007397
# ...               ...           ...           ...           ...           ...
# ZSCAN2       0.017781      0.126561      0.013664      0.010255      0.013543
# ZSCAN29      0.042534      0.311781      0.042256      0.063401      0.078897
# ZSCAN29      0.042534      0.311781      0.042256      0.063401      0.078897
# ZW10         0.555867      0.007427      0.071035      0.213754      0.169463
# ZW10         0.555867      0.007427      0.071035      0.213754      0.169463
#
#          ACH-000011_x  ACH-000012_x  ACH-000013_x  ACH-000014_x  ACH-000015_x  \
# AAK1         0.062314      0.052407      0.105416      0.060706      0.149773
# ABCC2        0.011782      0.058696      0.043512      0.022388      0.053242
# ABCG1        0.075231      0.108578      0.078840      0.024284      0.130939
# ABHD17C      0.009726      0.006413      0.023685      0.003270      0.003720
# ABHD17C      0.009726      0.006413      0.023685      0.003270      0.003720
# ...               ...           ...           ...           ...           ...
# ZSCAN2       0.010390      0.019206      0.009364      0.006569      0.029838
# ZSCAN29      0.006957      0.102415      0.025590      0.037839      0.026792
# ZSCAN29      0.006957      0.102415      0.025590      0.037839      0.026792
# ZW10         0.163544      0.128432      0.947852      0.130615      0.174493
# ZW10         0.163544      0.128432      0.947852      0.130615      0.174493
#
#          ...  ACH-001578  ACH-000036  ACH-000973  ACH-001128  ACH-000750  \
# AAK1     ...    2.400538    3.106013    3.426265    3.399171    2.722466
# ABCC2    ...    0.855990    4.250204    0.443607    1.333424    0.978196
# ABCG1    ...    0.137504    0.214125    0.042644    0.084064    0.000000
# ABHD17C  ...    2.829850    2.863938    3.316146    0.201634    2.570463
# ABHD17C  ...    2.829850    2.863938    3.316146    0.201634    2.570463
# ...      ...         ...         ...         ...         ...         ...
# ZSCAN2   ...    2.438293    3.085765    3.106013    2.863938    3.531069
# ZSCAN29  ...    3.713696    3.195348    3.371559    3.936402    3.182692
# ZSCAN29  ...    3.713696    3.195348    3.371559    3.936402    3.182692
# ZW10     ...    4.118526    2.247928    5.005400    4.213347    4.361768
# ZW10     ...    4.118526    2.247928    5.005400    4.213347    4.361768
#
#          ACH-000285  ACH-002669  ACH-001858  ACH-001997  ACH-000052
# AAK1       2.195348    2.063503    2.906891    2.049631    2.344828
# ABCC2      1.111031    0.536053    5.825786    0.565597    0.575312
# ABCG1      0.970854    0.863938    0.124328    0.189034    1.395063
# ABHD17C    4.865424    4.231893    3.498251    4.314697    2.134221
# ABHD17C    4.865424    4.231893    3.498251    4.314697    2.134221
# ...             ...         ...         ...         ...         ...
# ZSCAN2     3.467279    3.000000    3.127633    2.790772    3.782409
# ZSCAN29    4.412782    2.662205    2.935460    3.364572    3.555816
# ZSCAN29    4.412782    2.662205    2.935460    3.364572    3.555816
# ZW10       4.418190    3.349082    4.179511    3.889474    4.536675
# ZW10       4.418190    3.349082    4.179511    3.889474    4.536675
#
# [960 rows x 3578 columns]
# AAK1       False
# ABCC2      False
# ABCG1      False
# ABHD17C    False
# ABHD17C    False
#            ...
# ZSCAN2     False
# ZSCAN29    False
# ZSCAN29    False
# ZW10       False
# ZW10       False
# Name: label, Length: 960, dtype: bool

# %%
data_gene_dep = Data.iloc[:, 0:1086]
data_gene_dep;
data_gene_eff = Data.iloc[:, 1087:2172]
data_gene_eff;
data_express = Data.iloc[:, 2173:3578]
data_express;

# %%
pca = sklearn.decomposition.PCA(n_components=8, svd_solver='randomized')
X1 = pca.fit_transform(data_gene_dep)
print(pca.explained_variance_ratio_)
# Out:
# [0.85113288 0.0084742  0.00762432 0.00617622 0.0048388  0.00437109
#  0.00356805 0.00329834]

# %%
pca = sklearn.decomposition.PCA(n_components=8, svd_solver='randomized')
X2 = pca.fit_transform(data_gene_eff)
print(pca.explained_variance_ratio_)
# Out:
# [0.9052373  0.00598697 0.0054435  0.00437911 0.00340565 0.00269935
#  0.00247001 0.00198969]

# %%
pca = sklearn.decomposition.PCA(n_components=8, svd_solver='randomized')
X3 = pca.fit_transform(data_express)
print(pca.explained_variance_ratio_)
# Out:
# [0.83297736 0.02637972 0.01773364 0.01071045 0.00508367 0.00401742
#  0.00369112 0.00360801]

# %%
X4 = np.concatenate((X1, X2, X3), axis=1)
print(X4.shape)
# Out:
# (960, 24)

# %%
select = np.maximum(y, np.random.rand(len(y)) < sum(y)/(len(y) - sum(y)))
X4 = X4[select]
y = y[select]
print(X4.shape)
print(y.shape)
print(sum(y))
sns.scatterplot(x= X4[:,0], y=X4[:,1], hue=y)
plt.show()
# Out:
# (334, 24)
# (334,)
# 176

# %%
# Get the training and test data
X_train, X_test, y_train, y_test = train_test_split(X4, y, test_size=0.3)

# Fit the model
model = LogisticRegression(max_iter=10000).fit(X_train, y_train)

y_pred = model.predict(X_test)
y_pred_rt = model.predict_proba(X_test)[:, 1]

accuracy = str(accuracy_score(y_test, y_pred))
fpr, tpr, thresholds = roc_curve(y_test, y_pred_rt)
auc_value = str(auc(fpr, tpr))
precision = str(precision_score(y_test, y_pred))
recall = str(recall_score(y_test, y_pred))
f1score = str(f1_score(y_test, y_pred, average="weighted"))

# %%
print("Accuracy:" + accuracy)
print("Precision:" + precision)
print("Recall:" + recall)

conf_mx = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_mx)
plt.show()

print(conf_mx)
# Out:
# Accuracy:0.7128712871287128
# Precision:0.7636363636363637
# Recall:0.7241379310344828
# [[30 13]
#  [16 42]]

# %%
keras.backend.clear_session()
np.random.seed(50)
tf.random.set_seed(50)

# %%
K = keras.backend

class ExponentialLearningRate(keras.callbacks.Callback):
    def __init__(self, factor):
        self.factor = factor
        self.rates = []
        self.losses = []
    def on_batch_end(self, batch, logs):
        self.rates.append(K.get_value(self.model.optimizer.lr))
        self.losses.append(logs["loss"])
        K.set_value(self.model.optimizer.lr, self.model.optimizer.lr * self.factor)

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[24]),
    keras.layers.Dense(150, activation="relu"),
    keras.layers.Dense(75, activation="relu"),
    keras.layers.Dense(8, activation="softmax")
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 24)                0
#
#  dense (Dense)               (None, 150)               3750
#
#  dense_1 (Dense)             (None, 75)                11325
#
#  dense_2 (Dense)             (None, 8)                 608
#
# =================================================================
# Total params: 15,683
# Trainable params: 15,683
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(learning_rate=1e-3),
              metrics=["accuracy"])
expon_lr = ExponentialLearningRate(factor=1.005)

# %%
history = model.fit(X_train, y_train, epochs=5,
                    validation_data=(X_test, y_test),
                    callbacks=[expon_lr])
# Out:
# Epoch 1/5
# 8/8 [==============================] - 3s 103ms/step - loss: 2.8346 - accuracy: 0.4206 - val_loss: 2.0338 - val_accuracy: 0.4851
# Epoch 2/5
# 8/8 [==============================] - 0s 35ms/step - loss: 1.7211 - accuracy: 0.5064 - val_loss: 3.5381 - val_accuracy: 0.5446
# Epoch 3/5
# 8/8 [==============================] - 0s 30ms/step - loss: 1.7569 - accuracy: 0.5536 - val_loss: 1.5474 - val_accuracy: 0.5149
# Epoch 4/5
# 8/8 [==============================] - 0s 40ms/step - loss: 1.3673 - accuracy: 0.5622 - val_loss: 3.4295 - val_accuracy: 0.5545
# Epoch 5/5
# 8/8 [==============================] - 0s 37ms/step - loss: 1.4834 - accuracy: 0.5794 - val_loss: 2.8749 - val_accuracy: 0.4752

# %%
plt.plot(expon_lr.rates, expon_lr.losses)
plt.gca().set_xscale('log')
plt.hlines(min(expon_lr.losses), min(expon_lr.rates), max(expon_lr.rates))
plt.axis([min(expon_lr.rates), max(expon_lr.rates), 0, expon_lr.losses[0]])
plt.grid()
plt.xlabel("Learning rate")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')

# %%
print("Min Loss: " + str(min(expon_lr.losses)))
print("Best learning rate: " + str(expon_lr.rates[np.argmin(expon_lr.losses)]))
alpha = expon_lr.rates[np.argmin(expon_lr.losses)];
# Out:
# Min Loss: 1.1204642057418823
# Best learning rate: 0.0011327956

# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import layers, callbacks
keras.backend.clear_session()
np.random.seed(50)
tf.random.set_seed(50)

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[24]),
    keras.layers.Dense(150, activation="relu"),
    keras.layers.Dense(75, activation="relu"),
    keras.layers.Dense(8, activation="softmax")
])

# %%
#Using optimized learning rate: 
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(learning_rate=alpha),
              metrics=["accuracy"])

# %%
run_index = 1 # increment this at every run
run_logdir = os.path.join(os.curdir, "ovariantypes_logs", "run_{:03d}".format(run_index))
run_logdir
# Out:
# '.\\ovariantypes_logs\\run_001'

# %%
early_stopping_cb = keras.callbacks.EarlyStopping(
    min_delta=0.0005, # minimium amount of change to count as an improvement
    patience=20, # how many epochs to wait before stopping
)
checkpoint_cb = keras.callbacks.ModelCheckpoint("ovariantypes_model.h5", save_best_only=True)
tensorboard_cb = keras.callbacks.TensorBoard(run_logdir)

history = model.fit(X_train, y_train, epochs=200,
                    validation_data=(X_test, y_test),
                    callbacks=[checkpoint_cb, early_stopping_cb, tensorboard_cb])
# Out:
# Epoch 1/200
# 8/8 [==============================] - 2s 74ms/step - loss: 3.5220 - accuracy: 0.3348 - val_loss: 1.9188 - val_accuracy: 0.4158
# Epoch 2/200
# 8/8 [==============================] - 0s 69ms/step - loss: 1.4530 - accuracy: 0.4936 - val_loss: 1.5290 - val_accuracy: 0.4455
# Epoch 3/200
# 8/8 [==============================] - 0s 35ms/step - loss: 1.3716 - accuracy: 0.5708 - val_loss: 1.0521 - val_accuracy: 0.5644
# Epoch 4/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.9477 - accuracy: 0.6223 - val_loss: 0.8941 - val_accuracy: 0.6238
# Epoch 5/200
# 8/8 [==============================] - 0s 14ms/step - loss: 0.7789 - accuracy: 0.6567 - val_loss: 1.6806 - val_accuracy: 0.5248
# Epoch 6/200
# 8/8 [==============================] - 0s 13ms/step - loss: 0.9113 - accuracy: 0.6352 - val_loss: 1.1097 - val_accuracy: 0.5743
# Epoch 7/200
# 8/8 [==============================] - 0s 17ms/step - loss: 0.9670 - accuracy: 0.6652 - val_loss: 0.7177 - val_accuracy: 0.6040
# Epoch 8/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6793 - accuracy: 0.7082 - val_loss: 0.7014 - val_accuracy: 0.6040
# Epoch 9/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6780 - accuracy: 0.6695 - val_loss: 0.8450 - val_accuracy: 0.6238
# Epoch 10/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6972 - accuracy: 0.6867 - val_loss: 0.7226 - val_accuracy: 0.6139
# Epoch 11/200
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5925 - accuracy: 0.7468 - val_loss: 0.9251 - val_accuracy: 0.5644
# Epoch 12/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.7084 - accuracy: 0.6738 - val_loss: 0.8213 - val_accuracy: 0.6238
# Epoch 13/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.6436 - accuracy: 0.6996 - val_loss: 0.6965 - val_accuracy: 0.6337
# Epoch 14/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5260 - accuracy: 0.7682 - val_loss: 0.9196 - val_accuracy: 0.6337
# Epoch 15/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.7042 - accuracy: 0.6996 - val_loss: 0.9249 - val_accuracy: 0.6436
# Epoch 16/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6729 - accuracy: 0.6781 - val_loss: 0.7278 - val_accuracy: 0.6436
# Epoch 17/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6790 - accuracy: 0.6953 - val_loss: 0.9764 - val_accuracy: 0.5743
# Epoch 18/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.7347 - accuracy: 0.7253 - val_loss: 0.6825 - val_accuracy: 0.6733
# Epoch 19/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6594 - accuracy: 0.7382 - val_loss: 0.7911 - val_accuracy: 0.6931
# Epoch 20/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5811 - accuracy: 0.7554 - val_loss: 1.2902 - val_accuracy: 0.6436
# Epoch 21/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6110 - accuracy: 0.7468 - val_loss: 1.2828 - val_accuracy: 0.6436
# Epoch 22/200
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5294 - accuracy: 0.7811 - val_loss: 0.6638 - val_accuracy: 0.6832
# Epoch 23/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.4726 - accuracy: 0.7854 - val_loss: 0.6508 - val_accuracy: 0.7129
# Epoch 24/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5569 - accuracy: 0.7725 - val_loss: 0.7164 - val_accuracy: 0.6733
# Epoch 25/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.5301 - accuracy: 0.7597 - val_loss: 0.5726 - val_accuracy: 0.7624
# Epoch 26/200
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4537 - accuracy: 0.8112 - val_loss: 0.8185 - val_accuracy: 0.5941
# Epoch 27/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5319 - accuracy: 0.7597 - val_loss: 0.8857 - val_accuracy: 0.5941
# Epoch 28/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4806 - accuracy: 0.7511 - val_loss: 0.7074 - val_accuracy: 0.6832
# Epoch 29/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5500 - accuracy: 0.7468 - val_loss: 0.6395 - val_accuracy: 0.6931
# Epoch 30/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.4783 - accuracy: 0.7597 - val_loss: 0.7557 - val_accuracy: 0.6238
# Epoch 31/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5091 - accuracy: 0.7768 - val_loss: 0.5889 - val_accuracy: 0.7228
# Epoch 32/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.4721 - accuracy: 0.7940 - val_loss: 0.7249 - val_accuracy: 0.6931
# Epoch 33/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4641 - accuracy: 0.7940 - val_loss: 0.6632 - val_accuracy: 0.7228
# Epoch 34/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.4819 - accuracy: 0.7983 - val_loss: 1.8617 - val_accuracy: 0.5644
# Epoch 35/200
# 8/8 [==============================] - 0s 26ms/step - loss: 0.5317 - accuracy: 0.8112 - val_loss: 0.5128 - val_accuracy: 0.7624
# Epoch 36/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.4268 - accuracy: 0.8155 - val_loss: 0.5439 - val_accuracy: 0.7525
# Epoch 37/200
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4826 - accuracy: 0.7511 - val_loss: 1.9396 - val_accuracy: 0.6634
# Epoch 38/200
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5928 - accuracy: 0.8026 - val_loss: 0.5414 - val_accuracy: 0.7525
# Epoch 39/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6287 - accuracy: 0.7339 - val_loss: 1.1075 - val_accuracy: 0.6139
# Epoch 40/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4673 - accuracy: 0.8026 - val_loss: 0.7434 - val_accuracy: 0.6436
# Epoch 41/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.4752 - accuracy: 0.7811 - val_loss: 0.6162 - val_accuracy: 0.7327
# Epoch 42/200
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4188 - accuracy: 0.7854 - val_loss: 0.6347 - val_accuracy: 0.7327
# Epoch 43/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4770 - accuracy: 0.7854 - val_loss: 1.1587 - val_accuracy: 0.6139
# Epoch 44/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4367 - accuracy: 0.8283 - val_loss: 0.9759 - val_accuracy: 0.6238
# Epoch 45/200
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6779 - accuracy: 0.7682 - val_loss: 0.8723 - val_accuracy: 0.6733
# Epoch 46/200
# 8/8 [==============================] - 0s 12ms/step - loss: 0.4739 - accuracy: 0.8069 - val_loss: 0.5229 - val_accuracy: 0.7525
# Epoch 47/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4261 - accuracy: 0.7768 - val_loss: 0.6575 - val_accuracy: 0.6931
# Epoch 48/200
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5683 - accuracy: 0.7639 - val_loss: 0.5171 - val_accuracy: 0.7624
# Epoch 49/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.4752 - accuracy: 0.7854 - val_loss: 0.6002 - val_accuracy: 0.7624
# Epoch 50/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3857 - accuracy: 0.8112 - val_loss: 0.9785 - val_accuracy: 0.6931
# Epoch 51/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.5209 - accuracy: 0.8069 - val_loss: 0.4781 - val_accuracy: 0.7525
# Epoch 52/200
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3559 - accuracy: 0.8541 - val_loss: 0.8954 - val_accuracy: 0.6238
# Epoch 53/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.4314 - accuracy: 0.7940 - val_loss: 0.5628 - val_accuracy: 0.7426
# Epoch 54/200
# 8/8 [==============================] - 0s 12ms/step - loss: 0.3638 - accuracy: 0.8541 - val_loss: 0.5335 - val_accuracy: 0.7327
# Epoch 55/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3604 - accuracy: 0.8283 - val_loss: 0.5000 - val_accuracy: 0.7822
# Epoch 56/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3926 - accuracy: 0.8412 - val_loss: 0.4552 - val_accuracy: 0.8218
# Epoch 57/200
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3372 - accuracy: 0.8455 - val_loss: 0.6194 - val_accuracy: 0.7129
# Epoch 58/200
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4442 - accuracy: 0.8026 - val_loss: 0.6490 - val_accuracy: 0.8020
# Epoch 59/200
# 8/8 [==============================] - 0s 13ms/step - loss: 0.3784 - accuracy: 0.8541 - val_loss: 0.9737 - val_accuracy: 0.7327
# Epoch 60/200
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5359 - accuracy: 0.8197 - val_loss: 0.8205 - val_accuracy: 0.6634
# Epoch 61/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3673 - accuracy: 0.8326 - val_loss: 0.5075 - val_accuracy: 0.7525
# Epoch 62/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3958 - accuracy: 0.8326 - val_loss: 0.5906 - val_accuracy: 0.7426
# Epoch 63/200
# 8/8 [==============================] - 0s 13ms/step - loss: 0.3419 - accuracy: 0.8412 - val_loss: 0.5121 - val_accuracy: 0.7822
# Epoch 64/200
# 8/8 [==============================] - 0s 13ms/step - loss: 0.3601 - accuracy: 0.8412 - val_loss: 0.6781 - val_accuracy: 0.6832
# Epoch 65/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5037 - accuracy: 0.7725 - val_loss: 0.5043 - val_accuracy: 0.7624
# Epoch 66/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3878 - accuracy: 0.8197 - val_loss: 0.6793 - val_accuracy: 0.6733
# Epoch 67/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3735 - accuracy: 0.8369 - val_loss: 0.4781 - val_accuracy: 0.7921
# Epoch 68/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3296 - accuracy: 0.8584 - val_loss: 0.7099 - val_accuracy: 0.6733
# Epoch 69/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3811 - accuracy: 0.8369 - val_loss: 0.4906 - val_accuracy: 0.7525
# Epoch 70/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.3234 - accuracy: 0.8584 - val_loss: 0.4913 - val_accuracy: 0.7129
# Epoch 71/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.3821 - accuracy: 0.8283 - val_loss: 0.4752 - val_accuracy: 0.7921
# Epoch 72/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.3413 - accuracy: 0.8670 - val_loss: 0.5620 - val_accuracy: 0.7129
# Epoch 73/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.3389 - accuracy: 0.8326 - val_loss: 0.4826 - val_accuracy: 0.7822
# Epoch 74/200
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3327 - accuracy: 0.8627 - val_loss: 0.5406 - val_accuracy: 0.7327
# Epoch 75/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3110 - accuracy: 0.8670 - val_loss: 0.4436 - val_accuracy: 0.7921
# Epoch 76/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3186 - accuracy: 0.8498 - val_loss: 0.4389 - val_accuracy: 0.8218
# Epoch 77/200
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3607 - accuracy: 0.8541 - val_loss: 0.4735 - val_accuracy: 0.7426
# Epoch 78/200
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3296 - accuracy: 0.8627 - val_loss: 0.4638 - val_accuracy: 0.7624
# Epoch 79/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3060 - accuracy: 0.8541 - val_loss: 0.4962 - val_accuracy: 0.7525
# Epoch 80/200
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3144 - accuracy: 0.8584 - val_loss: 0.5962 - val_accuracy: 0.7228
# Epoch 81/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3312 - accuracy: 0.8841 - val_loss: 0.4223 - val_accuracy: 0.8218
# Epoch 82/200
# 8/8 [==============================] - 0s 12ms/step - loss: 0.3080 - accuracy: 0.8455 - val_loss: 0.6189 - val_accuracy: 0.7030
# Epoch 83/200
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3630 - accuracy: 0.8412 - val_loss: 0.5530 - val_accuracy: 0.7525
# Epoch 84/200
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3311 - accuracy: 0.8627 - val_loss: 0.5882 - val_accuracy: 0.7822
# Epoch 85/200
# 8/8 [==============================] - 0s 13ms/step - loss: 0.3286 - accuracy: 0.8798 - val_loss: 0.8141 - val_accuracy: 0.6238
# Epoch 86/200
# 8/8 [==============================] - 0s 13ms/step - loss: 0.3707 - accuracy: 0.8326 - val_loss: 0.4460 - val_accuracy: 0.7624
# Epoch 87/200
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3407 - accuracy: 0.8412 - val_loss: 0.8236 - val_accuracy: 0.7327
# Epoch 88/200
# 8/8 [==============================] - 0s 13ms/step - loss: 0.4571 - accuracy: 0.7940 - val_loss: 0.5360 - val_accuracy: 0.7822
# Epoch 89/200
# 8/8 [==============================] - 0s 12ms/step - loss: 0.3136 - accuracy: 0.8584 - val_loss: 0.4641 - val_accuracy: 0.7228
# Epoch 90/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.3037 - accuracy: 0.8841 - val_loss: 0.8050 - val_accuracy: 0.7228
# Epoch 91/200
# 8/8 [==============================] - 0s 13ms/step - loss: 0.3113 - accuracy: 0.8841 - val_loss: 0.6677 - val_accuracy: 0.7030
# Epoch 92/200
# 8/8 [==============================] - 0s 13ms/step - loss: 0.3639 - accuracy: 0.8369 - val_loss: 1.5431 - val_accuracy: 0.5941
# Epoch 93/200
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4503 - accuracy: 0.8412 - val_loss: 0.5960 - val_accuracy: 0.7723
# Epoch 94/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3823 - accuracy: 0.8155 - val_loss: 0.4280 - val_accuracy: 0.8119
# Epoch 95/200
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3102 - accuracy: 0.8627 - val_loss: 0.8087 - val_accuracy: 0.6238
# Epoch 96/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.4472 - accuracy: 0.8155 - val_loss: 0.4094 - val_accuracy: 0.8416
# Epoch 97/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3127 - accuracy: 0.8798 - val_loss: 0.4580 - val_accuracy: 0.7822
# Epoch 98/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3632 - accuracy: 0.8197 - val_loss: 1.1831 - val_accuracy: 0.7030
# Epoch 99/200
# 8/8 [==============================] - 0s 13ms/step - loss: 0.4143 - accuracy: 0.8412 - val_loss: 0.4574 - val_accuracy: 0.7822
# Epoch 100/200
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3163 - accuracy: 0.8670 - val_loss: 0.5378 - val_accuracy: 0.7525
# Epoch 101/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3527 - accuracy: 0.8283 - val_loss: 0.6676 - val_accuracy: 0.7921
# Epoch 102/200
# 8/8 [==============================] - 0s 13ms/step - loss: 0.3175 - accuracy: 0.8841 - val_loss: 0.6291 - val_accuracy: 0.7426
# Epoch 103/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3265 - accuracy: 0.8541 - val_loss: 0.4070 - val_accuracy: 0.8317
# Epoch 104/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3250 - accuracy: 0.8627 - val_loss: 0.6291 - val_accuracy: 0.7822
# Epoch 105/200
# 8/8 [==============================] - 0s 15ms/step - loss: 0.3235 - accuracy: 0.8670 - val_loss: 0.4406 - val_accuracy: 0.8416
# Epoch 106/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.2785 - accuracy: 0.8541 - val_loss: 0.4050 - val_accuracy: 0.8020
# Epoch 107/200
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3534 - accuracy: 0.8240 - val_loss: 0.4237 - val_accuracy: 0.8317
# Epoch 108/200
# 8/8 [==============================] - 0s 13ms/step - loss: 0.3322 - accuracy: 0.8240 - val_loss: 0.4180 - val_accuracy: 0.8416
# Epoch 109/200
# 8/8 [==============================] - 0s 14ms/step - loss: 0.2766 - accuracy: 0.8970 - val_loss: 0.4545 - val_accuracy: 0.7723
# Epoch 110/200
# 8/8 [==============================] - 0s 12ms/step - loss: 0.2863 - accuracy: 0.8755 - val_loss: 0.8526 - val_accuracy: 0.6337
# Epoch 111/200
# 8/8 [==============================] - 0s 13ms/step - loss: 0.3810 - accuracy: 0.8412 - val_loss: 0.4278 - val_accuracy: 0.8614
# Epoch 112/200
# 8/8 [==============================] - 0s 13ms/step - loss: 0.3247 - accuracy: 0.8670 - val_loss: 0.6592 - val_accuracy: 0.6832
# Epoch 113/200
# 8/8 [==============================] - 0s 13ms/step - loss: 0.3134 - accuracy: 0.8584 - val_loss: 0.5045 - val_accuracy: 0.7723
# Epoch 114/200
# 8/8 [==============================] - 0s 14ms/step - loss: 0.2899 - accuracy: 0.8584 - val_loss: 0.6658 - val_accuracy: 0.6931
# Epoch 115/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.3244 - accuracy: 0.8755 - val_loss: 0.5505 - val_accuracy: 0.7426
# Epoch 116/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.3345 - accuracy: 0.8541 - val_loss: 0.4254 - val_accuracy: 0.7921
# Epoch 117/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.3231 - accuracy: 0.8455 - val_loss: 0.6265 - val_accuracy: 0.7426
# Epoch 118/200
# 8/8 [==============================] - 0s 13ms/step - loss: 0.3626 - accuracy: 0.8455 - val_loss: 1.0038 - val_accuracy: 0.6535
# Epoch 119/200
# 8/8 [==============================] - 0s 12ms/step - loss: 0.3686 - accuracy: 0.8197 - val_loss: 0.5588 - val_accuracy: 0.7723
# Epoch 120/200
# 8/8 [==============================] - 0s 12ms/step - loss: 0.3084 - accuracy: 0.8712 - val_loss: 0.7377 - val_accuracy: 0.7723
# Epoch 121/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.3465 - accuracy: 0.8455 - val_loss: 0.4139 - val_accuracy: 0.8515
# Epoch 122/200
# 8/8 [==============================] - 0s 32ms/step - loss: 0.2764 - accuracy: 0.8798 - val_loss: 0.4761 - val_accuracy: 0.7624
# Epoch 123/200
# 8/8 [==============================] - 0s 17ms/step - loss: 0.2866 - accuracy: 0.8627 - val_loss: 0.4314 - val_accuracy: 0.8515
# Epoch 124/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.3223 - accuracy: 0.8498 - val_loss: 0.6539 - val_accuracy: 0.6832
# Epoch 125/200
# 8/8 [==============================] - 0s 13ms/step - loss: 0.3071 - accuracy: 0.8798 - val_loss: 0.4781 - val_accuracy: 0.7723
# Epoch 126/200
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3234 - accuracy: 0.8455 - val_loss: 0.4341 - val_accuracy: 0.8020

# %%
model = keras.models.load_model("ovariantypes_model.h5") # rollback to best model
model.evaluate(X_test, y_test)
model.evaluate(X_train, y_train)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4050 - accuracy: 0.8020
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2732 - accuracy: 0.8927
# [0.2732113301753998, 0.8927038908004761]

# %%
#Plot of Loss, Val_Loss, Accuracy and Val_Accuracy, with loss and val_loss normalized by max and min
hist = pd.DataFrame(history.history)#.plot(figsize=(8, 5))
hist['loss'] = (hist['loss'] - hist['loss'].min()) / (hist['loss'].max() - hist['loss'].min())
hist['val_loss'] = (hist['val_loss'] - hist['val_loss'].min()) / (hist['val_loss'].max() - hist['val_loss'].min())
hist.plot(figsize=(8,5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
 
plt.show()
