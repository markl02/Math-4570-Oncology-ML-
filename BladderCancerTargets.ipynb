# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import sklearn.decomposition
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import auc, accuracy_score, confusion_matrix, roc_curve, precision_score, recall_score, f1_score
import tensorflow as tf
from tensorflow import keras
import os

# %%
MergedData0 = pd.read_csv('Data.csv', index_col=0);
MergedData1 = MergedData0.iloc[:, :-1]
y = pd.read_csv("bladder_training_genes_set.csv", index_col='gene')
y.rename_axis("DepMap_ID")
y = y == 'positive'
data = MergedData1.merge(y, how='inner', left_index=True, right_index=True)
Data = data.iloc[:, :-1]
y = data.iloc[:, -1]
display(Data)
display(y)
# Out:
#          ACH-000001_x  ACH-000004_x  ACH-000005_x  ACH-000007_x  ACH-000009_x  \
# A2ML1        0.025962      0.033215      0.005448      0.011299      0.011721
# ABAT         0.069781      0.016261      0.132199      0.006714      0.017307
# ABAT         0.069781      0.016261      0.132199      0.006714      0.017307
# ACRBP        0.033464      0.066090      0.004191      0.021421      0.071012
# ACRBP        0.033464      0.066090      0.004191      0.021421      0.071012
# ...               ...           ...           ...           ...           ...
# ZNF639       0.022571      0.010000      0.010698      0.095480      0.044647
# ZNF75A       0.098515      0.124787      0.043134      0.131118      0.041215
# ZNF75A       0.098515      0.124787      0.043134      0.131118      0.041215
# ZSCAN21      0.029882      0.037909      0.150118      0.020868      0.066558
# ZSCAN25      0.048115      0.005255      0.002403      0.006739      0.023121
#
#          ACH-000011_x  ACH-000012_x  ACH-000013_x  ACH-000014_x  ACH-000015_x  \
# A2ML1        0.003488      0.002901      0.009602      0.015126      0.017902
# ABAT         0.052493      0.092392      0.047019      0.103188      0.073438
# ABAT         0.052493      0.092392      0.047019      0.103188      0.073438
# ACRBP        0.036759      0.009306      0.010147      0.077407      0.060633
# ACRBP        0.036759      0.009306      0.010147      0.077407      0.060633
# ...               ...           ...           ...           ...           ...
# ZNF639       0.132459      0.020875      0.029781      0.034463      0.017341
# ZNF75A       0.274883      0.155210      0.112361      0.068937      0.073185
# ZNF75A       0.274883      0.155210      0.112361      0.068937      0.073185
# ZSCAN21      0.015406      0.049785      0.035902      0.156008      0.048246
# ZSCAN25      0.043670      0.022613      0.055765      0.102448      0.009355
#
#          ...  ACH-001578  ACH-000036  ACH-000973  ACH-001128  ACH-000750  \
# A2ML1    ...    2.805292    0.000000    0.014355    0.000000    0.014355
# ABAT     ...    2.480265    0.454176    2.207893    1.495695    0.028569
# ABAT     ...    2.480265    0.454176    2.207893    1.495695    0.028569
# ACRBP    ...    0.731183    0.526069    0.097611    0.495695    0.124328
# ACRBP    ...    0.731183    0.526069    0.097611    0.495695    0.124328
# ...      ...         ...         ...         ...         ...         ...
# ZNF639   ...    6.418865    4.408032    5.246788    3.929791    4.460087
# ZNF75A   ...    4.481557    4.582556    3.624101    4.759156    3.653060
# ZNF75A   ...    4.481557    4.582556    3.624101    4.759156    3.653060
# ZSCAN21  ...    4.189034    3.477677    3.161888    3.682573    2.829850
# ZSCAN25  ...    3.137504    3.645010    2.974529    2.182692    2.260026
#
#          ACH-000285  ACH-002669  ACH-001858  ACH-001997  ACH-000052
# A2ML1      0.042644    0.000000    0.014355    0.250962    3.187451
# ABAT       1.372952    0.505891    2.253989    1.867896    3.680324
# ABAT       1.372952    0.505891    2.253989    1.867896    3.680324
# ACRBP      1.650765    1.310340    0.310340    1.007196    3.190615
# ACRBP      1.650765    1.310340    0.310340    1.007196    3.190615
# ...             ...         ...         ...         ...         ...
# ZNF639     5.639232    5.031219    4.554589    4.718636    4.916477
# ZNF75A     5.632559    1.144046    2.879706    3.481557    4.179511
# ZNF75A     5.632559    1.144046    2.879706    3.481557    4.179511
# ZSCAN21    4.139142    3.510962    3.106013    3.321928    3.757023
# ZSCAN25    4.126808    2.853996    2.493135    3.307429    3.463361
#
# [693 rows x 3578 columns]
# A2ML1      False
# ABAT       False
# ABAT       False
# ACRBP      False
# ACRBP      False
#            ...
# ZNF639     False
# ZNF75A     False
# ZNF75A     False
# ZSCAN21    False
# ZSCAN25    False
# Name: label, Length: 693, dtype: bool

# %%
data_gene_dep = Data.iloc[:, 0:1086]
data_gene_dep;
data_gene_eff = Data.iloc[:, 1087:2172]
data_gene_eff;
data_express = Data.iloc[:, 2173:3578]
data_express;

# %%
pca = sklearn.decomposition.PCA(n_components=8, svd_solver='randomized')
X1 = pca.fit_transform(data_gene_dep)
print(pca.explained_variance_ratio_)
# Out:
# [0.8783706  0.00631948 0.00528113 0.00461122 0.00363315 0.00333401
#  0.003062   0.00287346]

# %%
pca = sklearn.decomposition.PCA(n_components=8, svd_solver='randomized')
X2 = pca.fit_transform(data_gene_eff)
print(pca.explained_variance_ratio_)
# Out:
# [0.92189725 0.00651425 0.0039385  0.00280187 0.00252517 0.00230055
#  0.0019854  0.00177553]

# %%
pca = sklearn.decomposition.PCA(n_components=8, svd_solver='randomized')
X3 = pca.fit_transform(data_express)
print(pca.explained_variance_ratio_)
# Out:
# [0.80729064 0.02727207 0.02502088 0.01373563 0.00634261 0.00550459
#  0.00443939 0.00396117]

# %%
X4 = np.concatenate((X1, X2, X3), axis=1)
print(X4.shape)
# Out:
# (693, 24)

# %%
select = np.maximum(y, np.random.rand(len(y)) < sum(y)/(len(y) - sum(y)))
X4 = X4[select]
y = y[select]
print(X4.shape)
print(y.shape)
print(sum(y))
sns.scatterplot(x= X4[:,0], y=X4[:,1], hue=y)
plt.show()
# Out:
# (292, 24)
# (292,)
# 140

# %%
# Get the training and test data
X_train, X_test, y_train, y_test = train_test_split(X4, y, test_size=0.3)

# Fit the model
model = LogisticRegression(max_iter=10000).fit(X_train, y_train)

y_pred = model.predict(X_test)
y_pred_rt = model.predict_proba(X_test)[:, 1]

accuracy = str(accuracy_score(y_test, y_pred))
fpr, tpr, thresholds = roc_curve(y_test, y_pred_rt)
auc_value = str(auc(fpr, tpr))
precision = str(precision_score(y_test, y_pred))
recall = str(recall_score(y_test, y_pred))
f1score = str(f1_score(y_test, y_pred, average="weighted"))

# %%
print("Accuracy:" + accuracy)
print("Precision:" + precision)
print("Recall:" + recall)

conf_mx = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_mx)
plt.show()

print(conf_mx)
# Out:
# Accuracy:0.8068181818181818
# Precision:0.8787878787878788
# Recall:0.6904761904761905
# [[42  4]
#  [13 29]]

# %%
keras.backend.clear_session()
np.random.seed(50)
tf.random.set_seed(50)

# %%
K = keras.backend

class ExponentialLearningRate(keras.callbacks.Callback):
    def __init__(self, factor):
        self.factor = factor
        self.rates = []
        self.losses = []
    def on_batch_end(self, batch, logs):
        self.rates.append(K.get_value(self.model.optimizer.lr))
        self.losses.append(logs["loss"])
        K.set_value(self.model.optimizer.lr, self.model.optimizer.lr * self.factor)

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[24]),
    keras.layers.Dense(150, activation="relu"),
    keras.layers.Dense(75, activation="relu"),
    keras.layers.Dense(8, activation="softmax")
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 24)                0
#
#  dense (Dense)               (None, 150)               3750
#
#  dense_1 (Dense)             (None, 75)                11325
#
#  dense_2 (Dense)             (None, 8)                 608
#
# =================================================================
# Total params: 15,683
# Trainable params: 15,683
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(learning_rate=1e-3),
              metrics=["accuracy"])
expon_lr = ExponentialLearningRate(factor=1.005)

# %%
history = model.fit(X_train, y_train, epochs=5,
                    validation_data=(X_test, y_test),
                    callbacks=[expon_lr])
# Out:
# Epoch 1/5
# 1/7 [===>..........................] - ETA: 10s - loss: 26.1086 - accuracy: 0.0000e+00WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0014s vs `on_train_batch_end` time: 0.0017s). Check your callbacks.
# 7/7 [==============================] - 3s 224ms/step - loss: 8.5281 - accuracy: 0.1667 - val_loss: 2.8462 - val_accuracy: 0.4659
# Epoch 2/5
# 7/7 [==============================] - 0s 81ms/step - loss: 2.2624 - accuracy: 0.4461 - val_loss: 1.6258 - val_accuracy: 0.5455
# Epoch 3/5
# 7/7 [==============================] - 1s 216ms/step - loss: 1.3011 - accuracy: 0.5588 - val_loss: 2.2508 - val_accuracy: 0.4318
# Epoch 4/5
# 7/7 [==============================] - 1s 101ms/step - loss: 1.6334 - accuracy: 0.5343 - val_loss: 1.5480 - val_accuracy: 0.5795
# Epoch 5/5
# 7/7 [==============================] - 1s 111ms/step - loss: 1.5728 - accuracy: 0.5980 - val_loss: 1.4331 - val_accuracy: 0.5909

# %%
plt.plot(expon_lr.rates, expon_lr.losses)
plt.gca().set_xscale('log')
plt.hlines(min(expon_lr.losses), min(expon_lr.rates), max(expon_lr.rates))
plt.axis([min(expon_lr.rates), max(expon_lr.rates), 0, expon_lr.losses[0]])
plt.grid()
plt.xlabel("Learning rate")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')

# %%
print("Min Loss: " + str(min(expon_lr.losses)))
print("Best learning rate: " + str(expon_lr.rates[np.argmin(expon_lr.losses)]))
alpha = expon_lr.rates[np.argmin(expon_lr.losses)];
# Out:
# Min Loss: 1.261244535446167
# Best learning rate: 0.001155622

# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import layers, callbacks
keras.backend.clear_session()
np.random.seed(50)
tf.random.set_seed(50)

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[24]),
    keras.layers.Dense(150, activation="relu"),
    keras.layers.Dense(75, activation="relu"),
    keras.layers.Dense(8, activation="softmax")
])

# %%
#Using optimized learning rate: 
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(learning_rate=alpha),
              metrics=["accuracy"])

# %%
run_index = 1 # increment this at every run
run_logdir = os.path.join(os.curdir, "bladdertypes_logs", "run_{:03d}".format(run_index))
run_logdir
# Out:
# '.\\bladdertypes_logs\\run_001'

# %%
early_stopping_cb = keras.callbacks.EarlyStopping(
    min_delta=0.0005, # minimium amount of change to count as an improvement
    patience=20, # how many epochs to wait before stopping
)
checkpoint_cb = keras.callbacks.ModelCheckpoint("bladdertypes_model.h5", save_best_only=True)
tensorboard_cb = keras.callbacks.TensorBoard(run_logdir)

history = model.fit(X_train, y_train, epochs=200,
                    validation_data=(X_test, y_test),
                    callbacks=[checkpoint_cb, early_stopping_cb, tensorboard_cb])
# Out:
# Epoch 1/200
# 7/7 [==============================] - 2s 118ms/step - loss: 5.9858 - accuracy: 0.3039 - val_loss: 1.5881 - val_accuracy: 0.4886
# Epoch 2/200
# 7/7 [==============================] - 0s 43ms/step - loss: 1.3922 - accuracy: 0.6176 - val_loss: 1.4634 - val_accuracy: 0.6023
# Epoch 3/200
# 7/7 [==============================] - 0s 48ms/step - loss: 1.0640 - accuracy: 0.6373 - val_loss: 1.6251 - val_accuracy: 0.5000
# Epoch 4/200
# 7/7 [==============================] - 0s 63ms/step - loss: 1.0412 - accuracy: 0.6324 - val_loss: 0.7867 - val_accuracy: 0.6136
# Epoch 5/200
# 7/7 [==============================] - 0s 62ms/step - loss: 0.7697 - accuracy: 0.7157 - val_loss: 0.9528 - val_accuracy: 0.6477
# Epoch 6/200
# 7/7 [==============================] - 0s 41ms/step - loss: 0.7475 - accuracy: 0.7206 - val_loss: 0.8448 - val_accuracy: 0.5795
# Epoch 7/200
# 7/7 [==============================] - 0s 49ms/step - loss: 0.7865 - accuracy: 0.6912 - val_loss: 0.6896 - val_accuracy: 0.6477
# Epoch 8/200
# 7/7 [==============================] - 0s 53ms/step - loss: 0.6575 - accuracy: 0.7451 - val_loss: 0.5829 - val_accuracy: 0.7614
# Epoch 9/200
# 7/7 [==============================] - 0s 56ms/step - loss: 0.5939 - accuracy: 0.7794 - val_loss: 0.6326 - val_accuracy: 0.7159
# Epoch 10/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.6468 - accuracy: 0.7451 - val_loss: 0.8282 - val_accuracy: 0.6477
# Epoch 11/200
# 7/7 [==============================] - 1s 92ms/step - loss: 0.5582 - accuracy: 0.8186 - val_loss: 0.5985 - val_accuracy: 0.7159
# Epoch 12/200
# 7/7 [==============================] - 0s 62ms/step - loss: 0.6678 - accuracy: 0.7108 - val_loss: 0.7150 - val_accuracy: 0.7045
# Epoch 13/200
# 7/7 [==============================] - 1s 100ms/step - loss: 0.4838 - accuracy: 0.7941 - val_loss: 0.8226 - val_accuracy: 0.6250
# Epoch 14/200
# 7/7 [==============================] - 0s 64ms/step - loss: 0.5643 - accuracy: 0.7843 - val_loss: 0.4868 - val_accuracy: 0.7727
# Epoch 15/200
# 7/7 [==============================] - 0s 35ms/step - loss: 0.5408 - accuracy: 0.7745 - val_loss: 0.9107 - val_accuracy: 0.6932
# Epoch 16/200
# 7/7 [==============================] - 0s 56ms/step - loss: 0.7236 - accuracy: 0.7549 - val_loss: 0.6611 - val_accuracy: 0.7500
# Epoch 17/200
# 7/7 [==============================] - 1s 115ms/step - loss: 0.5286 - accuracy: 0.7598 - val_loss: 0.5625 - val_accuracy: 0.7273
# Epoch 18/200
# 7/7 [==============================] - 0s 62ms/step - loss: 0.4640 - accuracy: 0.7990 - val_loss: 1.3903 - val_accuracy: 0.7273
# Epoch 19/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.5892 - accuracy: 0.8088 - val_loss: 0.6506 - val_accuracy: 0.7159
# Epoch 20/200
# 7/7 [==============================] - 0s 65ms/step - loss: 0.5440 - accuracy: 0.7598 - val_loss: 0.6187 - val_accuracy: 0.6818
# Epoch 21/200
# 7/7 [==============================] - 0s 59ms/step - loss: 0.4345 - accuracy: 0.8284 - val_loss: 0.4713 - val_accuracy: 0.8068
# Epoch 22/200
# 7/7 [==============================] - 0s 49ms/step - loss: 0.4070 - accuracy: 0.8333 - val_loss: 0.9726 - val_accuracy: 0.7159
# Epoch 23/200
# 7/7 [==============================] - 0s 32ms/step - loss: 0.4662 - accuracy: 0.8529 - val_loss: 0.3991 - val_accuracy: 0.8182
# Epoch 24/200
# 7/7 [==============================] - 1s 113ms/step - loss: 0.3531 - accuracy: 0.8824 - val_loss: 0.3840 - val_accuracy: 0.8750
# Epoch 25/200
# 7/7 [==============================] - 0s 52ms/step - loss: 0.3654 - accuracy: 0.8873 - val_loss: 0.4001 - val_accuracy: 0.8409
# Epoch 26/200
# 7/7 [==============================] - 1s 92ms/step - loss: 0.3600 - accuracy: 0.8676 - val_loss: 0.3730 - val_accuracy: 0.8636
# Epoch 27/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.3376 - accuracy: 0.8922 - val_loss: 0.3911 - val_accuracy: 0.8523
# Epoch 28/200
# 7/7 [==============================] - 0s 39ms/step - loss: 0.3694 - accuracy: 0.8529 - val_loss: 0.4488 - val_accuracy: 0.7841
# Epoch 29/200
# 7/7 [==============================] - 0s 75ms/step - loss: 0.3575 - accuracy: 0.8529 - val_loss: 0.9102 - val_accuracy: 0.6818
# Epoch 30/200
# 7/7 [==============================] - 0s 16ms/step - loss: 0.6684 - accuracy: 0.7500 - val_loss: 0.4126 - val_accuracy: 0.8068
# Epoch 31/200
# 7/7 [==============================] - 0s 50ms/step - loss: 0.3265 - accuracy: 0.8873 - val_loss: 0.4079 - val_accuracy: 0.8068
# Epoch 32/200
# 7/7 [==============================] - 0s 39ms/step - loss: 0.3195 - accuracy: 0.8922 - val_loss: 0.3502 - val_accuracy: 0.8977
# Epoch 33/200
# 7/7 [==============================] - 0s 39ms/step - loss: 0.3264 - accuracy: 0.8971 - val_loss: 0.3708 - val_accuracy: 0.8523
# Epoch 34/200
# 7/7 [==============================] - 0s 56ms/step - loss: 0.3040 - accuracy: 0.8971 - val_loss: 0.3993 - val_accuracy: 0.8295
# Epoch 35/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.3510 - accuracy: 0.8676 - val_loss: 0.4939 - val_accuracy: 0.7727
# Epoch 36/200
# 7/7 [==============================] - 0s 20ms/step - loss: 0.3078 - accuracy: 0.8971 - val_loss: 0.3859 - val_accuracy: 0.7955
# Epoch 37/200
# 7/7 [==============================] - 0s 31ms/step - loss: 0.2957 - accuracy: 0.8922 - val_loss: 0.3238 - val_accuracy: 0.8750
# Epoch 38/200
# 7/7 [==============================] - 0s 30ms/step - loss: 0.3234 - accuracy: 0.9118 - val_loss: 0.3806 - val_accuracy: 0.8182
# Epoch 39/200
# 7/7 [==============================] - 0s 59ms/step - loss: 0.3313 - accuracy: 0.8676 - val_loss: 0.4691 - val_accuracy: 0.7500
# Epoch 40/200
# 7/7 [==============================] - 0s 39ms/step - loss: 0.3471 - accuracy: 0.8775 - val_loss: 0.3353 - val_accuracy: 0.8409
# Epoch 41/200
# 7/7 [==============================] - 0s 53ms/step - loss: 0.2915 - accuracy: 0.9118 - val_loss: 0.5103 - val_accuracy: 0.7614
# Epoch 42/200
# 7/7 [==============================] - 0s 17ms/step - loss: 0.2910 - accuracy: 0.8922 - val_loss: 0.3776 - val_accuracy: 0.8295
# Epoch 43/200
# 7/7 [==============================] - 0s 41ms/step - loss: 0.2688 - accuracy: 0.9363 - val_loss: 0.3744 - val_accuracy: 0.8068
# Epoch 44/200
# 7/7 [==============================] - 0s 43ms/step - loss: 0.2933 - accuracy: 0.8824 - val_loss: 0.3348 - val_accuracy: 0.8750
# Epoch 45/200
# 7/7 [==============================] - 1s 87ms/step - loss: 0.3001 - accuracy: 0.8873 - val_loss: 0.3223 - val_accuracy: 0.8864
# Epoch 46/200
# 7/7 [==============================] - 1s 119ms/step - loss: 0.2580 - accuracy: 0.9216 - val_loss: 0.3450 - val_accuracy: 0.8864
# Epoch 47/200
# 7/7 [==============================] - 0s 73ms/step - loss: 0.3145 - accuracy: 0.8725 - val_loss: 0.3391 - val_accuracy: 0.8750
# Epoch 48/200
# 7/7 [==============================] - 0s 40ms/step - loss: 0.2654 - accuracy: 0.8971 - val_loss: 0.5900 - val_accuracy: 0.8068
# Epoch 49/200
# 7/7 [==============================] - 1s 99ms/step - loss: 0.3103 - accuracy: 0.8922 - val_loss: 0.3448 - val_accuracy: 0.8182
# Epoch 50/200
# 7/7 [==============================] - 1s 81ms/step - loss: 0.2642 - accuracy: 0.9314 - val_loss: 0.3421 - val_accuracy: 0.8068
# Epoch 51/200
# 7/7 [==============================] - 0s 74ms/step - loss: 0.2753 - accuracy: 0.9069 - val_loss: 0.3110 - val_accuracy: 0.8409
# Epoch 52/200
# 7/7 [==============================] - 0s 43ms/step - loss: 0.2478 - accuracy: 0.9314 - val_loss: 0.3734 - val_accuracy: 0.8295
# Epoch 53/200
# 7/7 [==============================] - 0s 64ms/step - loss: 0.2398 - accuracy: 0.9265 - val_loss: 0.2897 - val_accuracy: 0.8864
# Epoch 54/200
# 7/7 [==============================] - 1s 128ms/step - loss: 0.2571 - accuracy: 0.9216 - val_loss: 0.2922 - val_accuracy: 0.8977
# Epoch 55/200
# 7/7 [==============================] - 0s 54ms/step - loss: 0.2324 - accuracy: 0.9559 - val_loss: 0.3026 - val_accuracy: 0.8864
# Epoch 56/200
# 7/7 [==============================] - 0s 63ms/step - loss: 0.2511 - accuracy: 0.9167 - val_loss: 0.3015 - val_accuracy: 0.8977
# Epoch 57/200
# 7/7 [==============================] - 1s 109ms/step - loss: 0.2486 - accuracy: 0.9363 - val_loss: 0.3100 - val_accuracy: 0.8750
# Epoch 58/200
# 7/7 [==============================] - 0s 55ms/step - loss: 0.2377 - accuracy: 0.9265 - val_loss: 0.3445 - val_accuracy: 0.8523
# Epoch 59/200
# 7/7 [==============================] - 0s 49ms/step - loss: 0.2374 - accuracy: 0.9167 - val_loss: 0.2814 - val_accuracy: 0.8864
# Epoch 60/200
# 7/7 [==============================] - 1s 87ms/step - loss: 0.2897 - accuracy: 0.8873 - val_loss: 0.3849 - val_accuracy: 0.8182
# Epoch 61/200
# 7/7 [==============================] - 0s 79ms/step - loss: 0.2630 - accuracy: 0.8971 - val_loss: 0.2878 - val_accuracy: 0.8636
# Epoch 62/200
# 7/7 [==============================] - 0s 42ms/step - loss: 0.2205 - accuracy: 0.9412 - val_loss: 0.2815 - val_accuracy: 0.8864
# Epoch 63/200
# 7/7 [==============================] - 0s 66ms/step - loss: 0.2391 - accuracy: 0.9167 - val_loss: 0.3227 - val_accuracy: 0.8636
# Epoch 64/200
# 7/7 [==============================] - 1s 87ms/step - loss: 0.2279 - accuracy: 0.9363 - val_loss: 0.3005 - val_accuracy: 0.8864
# Epoch 65/200
# 7/7 [==============================] - 0s 75ms/step - loss: 0.2323 - accuracy: 0.9510 - val_loss: 0.3560 - val_accuracy: 0.8295
# Epoch 66/200
# 7/7 [==============================] - 1s 88ms/step - loss: 0.2270 - accuracy: 0.9461 - val_loss: 0.2730 - val_accuracy: 0.8977
# Epoch 67/200
# 7/7 [==============================] - 0s 83ms/step - loss: 0.2089 - accuracy: 0.9608 - val_loss: 0.3921 - val_accuracy: 0.7955
# Epoch 68/200
# 7/7 [==============================] - 0s 50ms/step - loss: 0.2545 - accuracy: 0.8971 - val_loss: 0.3432 - val_accuracy: 0.8295
# Epoch 69/200
# 7/7 [==============================] - 0s 40ms/step - loss: 0.2176 - accuracy: 0.9363 - val_loss: 0.2966 - val_accuracy: 0.8636
# Epoch 70/200
# 7/7 [==============================] - 0s 61ms/step - loss: 0.2886 - accuracy: 0.8824 - val_loss: 0.8484 - val_accuracy: 0.7727
# Epoch 71/200
# 7/7 [==============================] - 0s 65ms/step - loss: 0.2532 - accuracy: 0.9314 - val_loss: 0.2864 - val_accuracy: 0.8523
# Epoch 72/200
# 7/7 [==============================] - 0s 37ms/step - loss: 0.2150 - accuracy: 0.9265 - val_loss: 0.2783 - val_accuracy: 0.8750
# Epoch 73/200
# 7/7 [==============================] - 0s 40ms/step - loss: 0.2177 - accuracy: 0.9216 - val_loss: 0.5052 - val_accuracy: 0.8068
# Epoch 74/200
# 7/7 [==============================] - 0s 53ms/step - loss: 0.2742 - accuracy: 0.9216 - val_loss: 0.2695 - val_accuracy: 0.8977
# Epoch 75/200
# 7/7 [==============================] - 0s 39ms/step - loss: 0.2030 - accuracy: 0.9510 - val_loss: 0.4603 - val_accuracy: 0.8068
# Epoch 76/200
# 7/7 [==============================] - 0s 50ms/step - loss: 0.2253 - accuracy: 0.9265 - val_loss: 0.2768 - val_accuracy: 0.8977
# Epoch 77/200
# 7/7 [==============================] - 0s 41ms/step - loss: 0.2033 - accuracy: 0.9559 - val_loss: 0.3062 - val_accuracy: 0.8523
# Epoch 78/200
# 7/7 [==============================] - 0s 51ms/step - loss: 0.1990 - accuracy: 0.9412 - val_loss: 0.2834 - val_accuracy: 0.8523
# Epoch 79/200
# 7/7 [==============================] - 0s 52ms/step - loss: 0.2018 - accuracy: 0.9461 - val_loss: 0.2810 - val_accuracy: 0.8409
# Epoch 80/200
# 7/7 [==============================] - 0s 51ms/step - loss: 0.1995 - accuracy: 0.9412 - val_loss: 0.2686 - val_accuracy: 0.8864
# Epoch 81/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.2111 - accuracy: 0.9265 - val_loss: 0.2667 - val_accuracy: 0.8864
# Epoch 82/200
# 7/7 [==============================] - 0s 42ms/step - loss: 0.1971 - accuracy: 0.9510 - val_loss: 0.2563 - val_accuracy: 0.9091
# Epoch 83/200
# 7/7 [==============================] - 0s 31ms/step - loss: 0.1914 - accuracy: 0.9510 - val_loss: 0.3835 - val_accuracy: 0.7727
# Epoch 84/200
# 7/7 [==============================] - 0s 47ms/step - loss: 0.2060 - accuracy: 0.9363 - val_loss: 0.2511 - val_accuracy: 0.9091
# Epoch 85/200
# 7/7 [==============================] - 0s 42ms/step - loss: 0.1945 - accuracy: 0.9608 - val_loss: 0.3074 - val_accuracy: 0.8636
# Epoch 86/200
# 7/7 [==============================] - 1s 94ms/step - loss: 0.2115 - accuracy: 0.9363 - val_loss: 0.3034 - val_accuracy: 0.8409
# Epoch 87/200
# 7/7 [==============================] - 0s 70ms/step - loss: 0.2352 - accuracy: 0.8971 - val_loss: 0.4050 - val_accuracy: 0.8182
# Epoch 88/200
# 7/7 [==============================] - 0s 30ms/step - loss: 0.2082 - accuracy: 0.9608 - val_loss: 0.2603 - val_accuracy: 0.8864
# Epoch 89/200
# 7/7 [==============================] - 0s 25ms/step - loss: 0.1786 - accuracy: 0.9510 - val_loss: 0.2665 - val_accuracy: 0.8636
# Epoch 90/200
# 7/7 [==============================] - 0s 37ms/step - loss: 0.2088 - accuracy: 0.9216 - val_loss: 0.2614 - val_accuracy: 0.8977
# Epoch 91/200
# 7/7 [==============================] - 0s 50ms/step - loss: 0.2205 - accuracy: 0.9265 - val_loss: 0.2581 - val_accuracy: 0.8864
# Epoch 92/200
# 7/7 [==============================] - 0s 19ms/step - loss: 0.1770 - accuracy: 0.9412 - val_loss: 0.2536 - val_accuracy: 0.8977
# Epoch 93/200
# 7/7 [==============================] - 0s 24ms/step - loss: 0.1968 - accuracy: 0.9461 - val_loss: 0.2474 - val_accuracy: 0.8864
# Epoch 94/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.1735 - accuracy: 0.9657 - val_loss: 0.2759 - val_accuracy: 0.8523
# Epoch 95/200
# 7/7 [==============================] - 0s 35ms/step - loss: 0.1777 - accuracy: 0.9510 - val_loss: 0.2416 - val_accuracy: 0.8864
# Epoch 96/200
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1718 - accuracy: 0.9657 - val_loss: 0.2576 - val_accuracy: 0.8977
# Epoch 97/200
# 7/7 [==============================] - 1s 92ms/step - loss: 0.1896 - accuracy: 0.9559 - val_loss: 0.2478 - val_accuracy: 0.8977
# Epoch 98/200
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1771 - accuracy: 0.9706 - val_loss: 0.2637 - val_accuracy: 0.8977
# Epoch 99/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.1912 - accuracy: 0.9461 - val_loss: 0.3115 - val_accuracy: 0.8182
# Epoch 100/200
# 7/7 [==============================] - 0s 20ms/step - loss: 0.2139 - accuracy: 0.9314 - val_loss: 0.2534 - val_accuracy: 0.8977
# Epoch 101/200
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1774 - accuracy: 0.9461 - val_loss: 0.2660 - val_accuracy: 0.8977
# Epoch 102/200
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1803 - accuracy: 0.9461 - val_loss: 0.2685 - val_accuracy: 0.8523
# Epoch 103/200
# 7/7 [==============================] - 0s 19ms/step - loss: 0.1816 - accuracy: 0.9559 - val_loss: 0.2487 - val_accuracy: 0.8977
# Epoch 104/200
# 7/7 [==============================] - 0s 19ms/step - loss: 0.1680 - accuracy: 0.9559 - val_loss: 0.2606 - val_accuracy: 0.8750
# Epoch 105/200
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1764 - accuracy: 0.9608 - val_loss: 0.2824 - val_accuracy: 0.8523
# Epoch 106/200
# 7/7 [==============================] - 0s 20ms/step - loss: 0.1889 - accuracy: 0.9461 - val_loss: 0.2410 - val_accuracy: 0.8977
# Epoch 107/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.1682 - accuracy: 0.9559 - val_loss: 0.2321 - val_accuracy: 0.8864
# Epoch 108/200
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1600 - accuracy: 0.9657 - val_loss: 0.2503 - val_accuracy: 0.8977
# Epoch 109/200
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1721 - accuracy: 0.9657 - val_loss: 0.2404 - val_accuracy: 0.8864
# Epoch 110/200
# 7/7 [==============================] - 0s 21ms/step - loss: 0.1641 - accuracy: 0.9657 - val_loss: 0.2554 - val_accuracy: 0.8523
# Epoch 111/200
# 7/7 [==============================] - 0s 25ms/step - loss: 0.1973 - accuracy: 0.9461 - val_loss: 0.3587 - val_accuracy: 0.8409
# Epoch 112/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.1888 - accuracy: 0.9510 - val_loss: 0.2505 - val_accuracy: 0.8750
# Epoch 113/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.1729 - accuracy: 0.9559 - val_loss: 0.2739 - val_accuracy: 0.8750
# Epoch 114/200
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1968 - accuracy: 0.9461 - val_loss: 0.2389 - val_accuracy: 0.8977
# Epoch 115/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.1572 - accuracy: 0.9804 - val_loss: 0.2387 - val_accuracy: 0.8977
# Epoch 116/200
# 7/7 [==============================] - 0s 19ms/step - loss: 0.1680 - accuracy: 0.9559 - val_loss: 0.2587 - val_accuracy: 0.8750
# Epoch 117/200
# 7/7 [==============================] - 0s 18ms/step - loss: 0.1812 - accuracy: 0.9559 - val_loss: 0.3234 - val_accuracy: 0.8636
# Epoch 118/200
# 7/7 [==============================] - 0s 20ms/step - loss: 0.1711 - accuracy: 0.9608 - val_loss: 0.2348 - val_accuracy: 0.8864
# Epoch 119/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.1525 - accuracy: 0.9608 - val_loss: 0.2624 - val_accuracy: 0.8977
# Epoch 120/200
# 7/7 [==============================] - 0s 26ms/step - loss: 0.1590 - accuracy: 0.9706 - val_loss: 0.2292 - val_accuracy: 0.8864
# Epoch 121/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.2392 - accuracy: 0.9020 - val_loss: 0.2469 - val_accuracy: 0.8977
# Epoch 122/200
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1681 - accuracy: 0.9657 - val_loss: 0.2309 - val_accuracy: 0.8864
# Epoch 123/200
# 7/7 [==============================] - 0s 20ms/step - loss: 0.1555 - accuracy: 0.9755 - val_loss: 0.5474 - val_accuracy: 0.7955
# Epoch 124/200
# 7/7 [==============================] - 0s 19ms/step - loss: 0.2070 - accuracy: 0.9314 - val_loss: 0.2445 - val_accuracy: 0.8977
# Epoch 125/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.1540 - accuracy: 0.9755 - val_loss: 0.2582 - val_accuracy: 0.8977
# Epoch 126/200
# 7/7 [==============================] - 0s 24ms/step - loss: 0.1548 - accuracy: 0.9755 - val_loss: 0.2288 - val_accuracy: 0.8977
# Epoch 127/200
# 7/7 [==============================] - 0s 19ms/step - loss: 0.1546 - accuracy: 0.9608 - val_loss: 0.2403 - val_accuracy: 0.8977
# Epoch 128/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.1491 - accuracy: 0.9755 - val_loss: 0.2325 - val_accuracy: 0.8977
# Epoch 129/200
# 7/7 [==============================] - 0s 18ms/step - loss: 0.1603 - accuracy: 0.9755 - val_loss: 0.2547 - val_accuracy: 0.8977
# Epoch 130/200
# 7/7 [==============================] - 0s 21ms/step - loss: 0.1491 - accuracy: 0.9706 - val_loss: 0.2257 - val_accuracy: 0.8977
# Epoch 131/200
# 7/7 [==============================] - 0s 20ms/step - loss: 0.1537 - accuracy: 0.9608 - val_loss: 0.2871 - val_accuracy: 0.8636
# Epoch 132/200
# 7/7 [==============================] - 0s 24ms/step - loss: 0.1552 - accuracy: 0.9510 - val_loss: 0.2204 - val_accuracy: 0.9091
# Epoch 133/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.1501 - accuracy: 0.9706 - val_loss: 0.3258 - val_accuracy: 0.8295
# Epoch 134/200
# 7/7 [==============================] - 0s 21ms/step - loss: 0.1557 - accuracy: 0.9608 - val_loss: 0.2619 - val_accuracy: 0.8523
# Epoch 135/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.1397 - accuracy: 0.9755 - val_loss: 0.2767 - val_accuracy: 0.8750
# Epoch 136/200
# 7/7 [==============================] - 0s 18ms/step - loss: 0.1417 - accuracy: 0.9804 - val_loss: 0.2314 - val_accuracy: 0.8977
# Epoch 137/200
# 7/7 [==============================] - 0s 20ms/step - loss: 0.1616 - accuracy: 0.9657 - val_loss: 0.2246 - val_accuracy: 0.8864
# Epoch 138/200
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1420 - accuracy: 0.9706 - val_loss: 0.2439 - val_accuracy: 0.8864
# Epoch 139/200
# 7/7 [==============================] - 0s 25ms/step - loss: 0.1403 - accuracy: 0.9657 - val_loss: 0.2191 - val_accuracy: 0.9091
# Epoch 140/200
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1406 - accuracy: 0.9804 - val_loss: 0.2645 - val_accuracy: 0.8750
# Epoch 141/200
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1521 - accuracy: 0.9559 - val_loss: 0.2200 - val_accuracy: 0.8864
# Epoch 142/200
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1429 - accuracy: 0.9706 - val_loss: 0.2418 - val_accuracy: 0.8977
# Epoch 143/200
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1389 - accuracy: 0.9804 - val_loss: 0.2265 - val_accuracy: 0.8977
# Epoch 144/200
# 7/7 [==============================] - 0s 18ms/step - loss: 0.1354 - accuracy: 0.9853 - val_loss: 0.2172 - val_accuracy: 0.8864
# Epoch 145/200
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1397 - accuracy: 0.9853 - val_loss: 0.2632 - val_accuracy: 0.8636
# Epoch 146/200
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1482 - accuracy: 0.9510 - val_loss: 0.2995 - val_accuracy: 0.8409
# Epoch 147/200
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1566 - accuracy: 0.9510 - val_loss: 0.2334 - val_accuracy: 0.9091
# Epoch 148/200
# 7/7 [==============================] - 0s 19ms/step - loss: 0.1374 - accuracy: 0.9804 - val_loss: 0.2458 - val_accuracy: 0.8977
# Epoch 149/200
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1408 - accuracy: 0.9755 - val_loss: 0.2198 - val_accuracy: 0.8864
# Epoch 150/200
# 7/7 [==============================] - 0s 18ms/step - loss: 0.1414 - accuracy: 0.9755 - val_loss: 0.2685 - val_accuracy: 0.8523
# Epoch 151/200
# 7/7 [==============================] - 0s 20ms/step - loss: 0.1427 - accuracy: 0.9706 - val_loss: 0.2144 - val_accuracy: 0.8864
# Epoch 152/200
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1235 - accuracy: 0.9706 - val_loss: 0.2539 - val_accuracy: 0.8750
# Epoch 153/200
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1474 - accuracy: 0.9608 - val_loss: 0.2220 - val_accuracy: 0.9091
# Epoch 154/200
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1324 - accuracy: 0.9853 - val_loss: 0.2152 - val_accuracy: 0.8864
# Epoch 155/200
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1290 - accuracy: 0.9706 - val_loss: 0.2948 - val_accuracy: 0.8750
# Epoch 156/200
# 7/7 [==============================] - 0s 20ms/step - loss: 0.1511 - accuracy: 0.9608 - val_loss: 0.2106 - val_accuracy: 0.8864
# Epoch 157/200
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1308 - accuracy: 0.9755 - val_loss: 0.2512 - val_accuracy: 0.8523
# Epoch 158/200
# 7/7 [==============================] - 0s 18ms/step - loss: 0.1513 - accuracy: 0.9657 - val_loss: 0.2347 - val_accuracy: 0.9091
# Epoch 159/200
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1513 - accuracy: 0.9706 - val_loss: 0.2441 - val_accuracy: 0.9091
# Epoch 160/200
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1492 - accuracy: 0.9657 - val_loss: 0.2372 - val_accuracy: 0.8523
# Epoch 161/200
# 7/7 [==============================] - 0s 18ms/step - loss: 0.1319 - accuracy: 0.9657 - val_loss: 0.2384 - val_accuracy: 0.8864
# Epoch 162/200
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1273 - accuracy: 0.9902 - val_loss: 0.2344 - val_accuracy: 0.8864
# Epoch 163/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.1412 - accuracy: 0.9510 - val_loss: 0.2170 - val_accuracy: 0.8977
# Epoch 164/200
# 7/7 [==============================] - 0s 19ms/step - loss: 0.1505 - accuracy: 0.9559 - val_loss: 0.2148 - val_accuracy: 0.8977
# Epoch 165/200
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1213 - accuracy: 0.9902 - val_loss: 0.2796 - val_accuracy: 0.8636
# Epoch 166/200
# 7/7 [==============================] - 0s 18ms/step - loss: 0.1309 - accuracy: 0.9706 - val_loss: 0.2598 - val_accuracy: 0.8636
# Epoch 167/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.1584 - accuracy: 0.9559 - val_loss: 0.2113 - val_accuracy: 0.8977
# Epoch 168/200
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1279 - accuracy: 0.9853 - val_loss: 0.2364 - val_accuracy: 0.9091
# Epoch 169/200
# 7/7 [==============================] - 0s 19ms/step - loss: 0.1489 - accuracy: 0.9559 - val_loss: 0.2263 - val_accuracy: 0.9091
# Epoch 170/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.1196 - accuracy: 0.9902 - val_loss: 0.2484 - val_accuracy: 0.8636
# Epoch 171/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.1399 - accuracy: 0.9706 - val_loss: 0.2304 - val_accuracy: 0.9091
# Epoch 172/200
# 7/7 [==============================] - 0s 19ms/step - loss: 0.1304 - accuracy: 0.9755 - val_loss: 0.2882 - val_accuracy: 0.8636
# Epoch 173/200
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1624 - accuracy: 0.9559 - val_loss: 0.3746 - val_accuracy: 0.8182
# Epoch 174/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.1457 - accuracy: 0.9559 - val_loss: 0.2066 - val_accuracy: 0.8977
# Epoch 175/200
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1225 - accuracy: 0.9804 - val_loss: 0.2088 - val_accuracy: 0.9205
# Epoch 176/200
# 7/7 [==============================] - 0s 18ms/step - loss: 0.1209 - accuracy: 0.9853 - val_loss: 0.2632 - val_accuracy: 0.8636
# Epoch 177/200
# 7/7 [==============================] - 0s 18ms/step - loss: 0.1406 - accuracy: 0.9608 - val_loss: 0.2187 - val_accuracy: 0.9091
# Epoch 178/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.1329 - accuracy: 0.9804 - val_loss: 0.2045 - val_accuracy: 0.8864
# Epoch 179/200
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1219 - accuracy: 0.9755 - val_loss: 0.2304 - val_accuracy: 0.8750
# Epoch 180/200
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1283 - accuracy: 0.9706 - val_loss: 0.3305 - val_accuracy: 0.8523
# Epoch 181/200
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1514 - accuracy: 0.9559 - val_loss: 0.2130 - val_accuracy: 0.8977
# Epoch 182/200
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1546 - accuracy: 0.9461 - val_loss: 0.2579 - val_accuracy: 0.8636
# Epoch 183/200
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1326 - accuracy: 0.9706 - val_loss: 0.2111 - val_accuracy: 0.8977
# Epoch 184/200
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1224 - accuracy: 0.9853 - val_loss: 0.2814 - val_accuracy: 0.8636
# Epoch 185/200
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1280 - accuracy: 0.9608 - val_loss: 0.2178 - val_accuracy: 0.9091
# Epoch 186/200
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1345 - accuracy: 0.9657 - val_loss: 0.2050 - val_accuracy: 0.9091
# Epoch 187/200
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1305 - accuracy: 0.9657 - val_loss: 0.2083 - val_accuracy: 0.9205
# Epoch 188/200
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1262 - accuracy: 0.9853 - val_loss: 0.2920 - val_accuracy: 0.8523
# Epoch 189/200
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1567 - accuracy: 0.9510 - val_loss: 0.2235 - val_accuracy: 0.8636
# Epoch 190/200
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1483 - accuracy: 0.9412 - val_loss: 0.2180 - val_accuracy: 0.9091
# Epoch 191/200
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1204 - accuracy: 0.9804 - val_loss: 0.2116 - val_accuracy: 0.8977
# Epoch 192/200
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1143 - accuracy: 0.9804 - val_loss: 0.2094 - val_accuracy: 0.9091
# Epoch 193/200
# 7/7 [==============================] - 0s 19ms/step - loss: 0.1152 - accuracy: 0.9755 - val_loss: 0.2058 - val_accuracy: 0.8977
# Epoch 194/200
# 7/7 [==============================] - 0s 20ms/step - loss: 0.1114 - accuracy: 0.9804 - val_loss: 0.2011 - val_accuracy: 0.8864
# Epoch 195/200
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1179 - accuracy: 0.9804 - val_loss: 0.2503 - val_accuracy: 0.8750
# Epoch 196/200
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1133 - accuracy: 0.9755 - val_loss: 0.2134 - val_accuracy: 0.9091
# Epoch 197/200
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1269 - accuracy: 0.9657 - val_loss: 0.2022 - val_accuracy: 0.8864
# Epoch 198/200
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1128 - accuracy: 0.9755 - val_loss: 0.2324 - val_accuracy: 0.9091
# Epoch 199/200
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1357 - accuracy: 0.9657 - val_loss: 0.2138 - val_accuracy: 0.9205
# Epoch 200/200
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1154 - accuracy: 0.9853 - val_loss: 0.2470 - val_accuracy: 0.9091

# %%
model = keras.models.load_model("bladdertypes_model.h5") # rollback to best model
model.evaluate(X_test, y_test)
model.evaluate(X_train, y_train)
# Out:
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2011 - accuracy: 0.8864
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1083 - accuracy: 0.9706
# [0.10834743827581406, 0.970588207244873]

# %%
#Plot of Loss, Val_Loss, Accuracy and Val_Accuracy, with loss and val_loss normalized by max and min
hist = pd.DataFrame(history.history)#.plot(figsize=(8, 5))
hist['loss'] = (hist['loss'] - hist['loss'].min()) / (hist['loss'].max() - hist['loss'].min())
hist['val_loss'] = (hist['val_loss'] - hist['val_loss'].min()) / (hist['val_loss'].max() - hist['val_loss'].min())
hist.plot(figsize=(8,5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
 
plt.show()
