# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import sklearn.decomposition
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import auc, accuracy_score, confusion_matrix, roc_curve, precision_score, recall_score, f1_score
import tensorflow as tf
from tensorflow import keras
import os

# %%
MergedData0 = pd.read_csv('Data.csv', index_col=0);
MergedData1 = MergedData0.iloc[:, :-1]
y = pd.read_csv("liver_training_genes_set.csv", index_col='gene')
y.rename_axis("DepMap_ID")
y = y == 'positive'
data = MergedData1.merge(y, how='inner', left_index=True, right_index=True)
Data = data.iloc[:, :-1]
y = data.iloc[:, -1]
display(Data)
display(y)
# Out:
#         ACH-000001_x  ACH-000004_x  ACH-000005_x  ACH-000007_x  ACH-000009_x  \
# ABCA5       0.056234      0.007182      0.016045      0.014620      0.243083
# ABHD11      0.018263      0.340513      0.890299      0.466574      0.348207
# ABHD2       0.116405      0.268107      0.200036      0.031650      0.033103
# ABL1        0.140990      0.037457      0.013804      0.033141      0.038988
# ABL1        0.140990      0.037457      0.013804      0.033141      0.038988
# ...              ...           ...           ...           ...           ...
# ZNF606      0.017374      0.030757      0.031110      0.056030      0.073800
# ZNF708      0.062490      0.018045      0.220300      0.031664      0.016184
# ZNF829      0.507594      0.030491      0.008762      0.013934      0.033136
# ZW10        0.555867      0.007427      0.071035      0.213754      0.169463
# ZW10        0.555867      0.007427      0.071035      0.213754      0.169463
#
#         ACH-000011_x  ACH-000012_x  ACH-000013_x  ACH-000014_x  ACH-000015_x  \
# ABCA5       0.044001      0.062608      0.035263      0.071584      0.193514
# ABHD11      0.142382      0.094959      0.105880      0.276472      0.049174
# ABHD2       0.026910      0.078480      0.077381      0.003140      0.019778
# ABL1        0.369726      0.030876      0.045682      0.011350      0.026241
# ABL1        0.369726      0.030876      0.045682      0.011350      0.026241
# ...              ...           ...           ...           ...           ...
# ZNF606      0.087961      0.077748      0.129336      0.047205      0.014985
# ZNF708      0.038199      0.071495      0.036997      0.001073      0.027757
# ZNF829      0.031007      0.052977      0.281235      0.001569      0.090657
# ZW10        0.163544      0.128432      0.947852      0.130615      0.174493
# ZW10        0.163544      0.128432      0.947852      0.130615      0.174493
#
#         ...  ACH-001578  ACH-000036  ACH-000973  ACH-001128  ACH-000750  \
# ABCA5   ...    0.565597    1.735522    2.163499    2.117695    0.056584
# ABHD11  ...    2.604071    3.716991    4.499527    6.341630    3.544733
# ABHD2   ...    3.388190    3.925050    3.699330    4.954662    4.424250
# ABL1    ...    4.084064    5.264536    4.421560    4.858478    6.607182
# ABL1    ...    4.084064    5.264536    4.421560    4.858478    6.607182
# ...     ...         ...         ...         ...         ...         ...
# ZNF606  ...    2.214125    0.650765    1.389567    3.008989    0.028569
# ZNF708  ...    3.407353    1.389567    2.990955    2.339137    1.735522
# ZNF829  ...    2.066950    0.263034    1.505891    1.389567    0.000000
# ZW10    ...    4.118526    2.247928    5.005400    4.213347    4.361768
# ZW10    ...    4.118526    2.247928    5.005400    4.213347    4.361768
#
#         ACH-000285  ACH-002669  ACH-001858  ACH-001997  ACH-000052
# ABCA5     1.959770    1.914565    2.684819    1.761285    3.602884
# ABHD11    4.361768    4.699330    4.130931    6.039358    3.872829
# ABHD2     3.232661    5.579542    4.564988    5.003602    4.137504
# ABL1      4.311794    3.855990    5.281327    3.840967    5.545351
# ABL1      4.311794    3.855990    5.281327    3.840967    5.545351
# ...            ...         ...         ...         ...         ...
# ZNF606    0.097611    0.000000    1.560715    2.140779    3.257011
# ZNF708    3.454176    3.754888    1.084064    2.035624    2.689299
# ZNF829    0.124328    0.084064    0.321928    0.992768    1.304511
# ZW10      4.418190    3.349082    4.179511    3.889474    4.536675
# ZW10      4.418190    3.349082    4.179511    3.889474    4.536675
#
# [768 rows x 3578 columns]
# ABCA5     False
# ABHD11    False
# ABHD2     False
# ABL1       True
# ABL1       True
#           ...
# ZNF606    False
# ZNF708    False
# ZNF829    False
# ZW10      False
# ZW10      False
# Name: label, Length: 768, dtype: bool

# %%
data_gene_dep = Data.iloc[:, 0:1086]
data_gene_dep;
data_gene_eff = Data.iloc[:, 1087:2172]
data_gene_eff;
data_express = Data.iloc[:, 2173:3578]
data_express;

# %%
pca = sklearn.decomposition.PCA(n_components=8, svd_solver='randomized')
X1 = pca.fit_transform(data_gene_dep)
print(pca.explained_variance_ratio_)
# Out:
# [0.80943768 0.01168353 0.01029823 0.00928647 0.00734167 0.00673281
#  0.00582183 0.00456114]

# %%
pca = sklearn.decomposition.PCA(n_components=8, svd_solver='randomized')
X2 = pca.fit_transform(data_gene_eff)
print(pca.explained_variance_ratio_)
# Out:
# [0.84955144 0.00939059 0.00759537 0.00737585 0.00472253 0.00446916
#  0.00392118 0.00368736]

# %%
pca = sklearn.decomposition.PCA(n_components=8, svd_solver='randomized')
X3 = pca.fit_transform(data_express)
print(pca.explained_variance_ratio_)
# Out:
# [0.77748009 0.03308899 0.02462447 0.01384411 0.00730882 0.0061401
#  0.00518632 0.00476601]

# %%
X4 = np.concatenate((X1, X2, X3), axis=1)
print(X4.shape)
# Out:
# (768, 24)

# %%
select = np.maximum(y, np.random.rand(len(y)) < sum(y)/(len(y) - sum(y)))
X4 = X4[select]
y = y[select]
print(X4.shape)
print(y.shape)
print(sum(y))
sns.scatterplot(x= X4[:,0], y=X4[:,1], hue=y)
plt.show()
# Out:
# (304, 24)
# (304,)
# 149

# %%
# Get the training and test data
X_train, X_test, y_train, y_test = train_test_split(X4, y, test_size=0.3)

# Fit the model
model = LogisticRegression(max_iter=10000).fit(X_train, y_train)

y_pred = model.predict(X_test)
y_pred_rt = model.predict_proba(X_test)[:, 1]

accuracy = str(accuracy_score(y_test, y_pred))
fpr, tpr, thresholds = roc_curve(y_test, y_pred_rt)
auc_value = str(auc(fpr, tpr))
precision = str(precision_score(y_test, y_pred))
recall = str(recall_score(y_test, y_pred))
f1score = str(f1_score(y_test, y_pred, average="weighted"))

# %%
print("Accuracy:" + accuracy)
print("Precision:" + precision)
print("Recall:" + recall)

conf_mx = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_mx)
plt.show()

print(conf_mx)
# Out:
# Accuracy:0.6195652173913043
# Precision:0.6571428571428571
# Recall:0.5
# [[34 12]
#  [23 23]]

# %%
keras.backend.clear_session()
np.random.seed(50)
tf.random.set_seed(50)

# %%
K = keras.backend

class ExponentialLearningRate(keras.callbacks.Callback):
    def __init__(self, factor):
        self.factor = factor
        self.rates = []
        self.losses = []
    def on_batch_end(self, batch, logs):
        self.rates.append(K.get_value(self.model.optimizer.lr))
        self.losses.append(logs["loss"])
        K.set_value(self.model.optimizer.lr, self.model.optimizer.lr * self.factor)

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[24]),
    keras.layers.Dense(150, activation="relu"),
    keras.layers.Dense(75, activation="relu"),
    keras.layers.Dense(8, activation="softmax")
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 24)                0
#
#  dense (Dense)               (None, 150)               3750
#
#  dense_1 (Dense)             (None, 75)                11325
#
#  dense_2 (Dense)             (None, 8)                 608
#
# =================================================================
# Total params: 15,683
# Trainable params: 15,683
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(learning_rate=1e-3),
              metrics=["accuracy"])
expon_lr = ExponentialLearningRate(factor=1.005)

# %%
history = model.fit(X_train, y_train, epochs=5,
                    validation_data=(X_test, y_test),
                    callbacks=[expon_lr])
# Out:
# Epoch 1/5
# 7/7 [==============================] - 3s 172ms/step - loss: 3.6662 - accuracy: 0.3538 - val_loss: 2.1499 - val_accuracy: 0.5109
# Epoch 2/5
# 7/7 [==============================] - 0s 34ms/step - loss: 1.7927 - accuracy: 0.4575 - val_loss: 1.7053 - val_accuracy: 0.4891
# Epoch 3/5
# 7/7 [==============================] - 0s 63ms/step - loss: 1.4200 - accuracy: 0.5000 - val_loss: 1.4805 - val_accuracy: 0.5109
# Epoch 4/5
# 7/7 [==============================] - 0s 79ms/step - loss: 1.0687 - accuracy: 0.5566 - val_loss: 1.2329 - val_accuracy: 0.5543
# Epoch 5/5
# 7/7 [==============================] - 0s 49ms/step - loss: 0.9894 - accuracy: 0.5566 - val_loss: 1.5267 - val_accuracy: 0.5217

# %%
plt.plot(expon_lr.rates, expon_lr.losses)
plt.gca().set_xscale('log')
plt.hlines(min(expon_lr.losses), min(expon_lr.rates), max(expon_lr.rates))
plt.axis([min(expon_lr.rates), max(expon_lr.rates), 0, expon_lr.losses[0]])
plt.grid()
plt.xlabel("Learning rate")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')

# %%
print("Min Loss: " + str(min(expon_lr.losses)))
print("Best learning rate: " + str(expon_lr.rates[np.argmin(expon_lr.losses)]))
alpha = expon_lr.rates[np.argmin(expon_lr.losses)];
# Out:
# Min Loss: 0.944497287273407
# Best learning rate: 0.0011730432

# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import layers, callbacks
keras.backend.clear_session()
np.random.seed(50)
tf.random.set_seed(50)

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[24]),
    keras.layers.Dense(150, activation="relu"),
    keras.layers.Dense(75, activation="relu"),
    keras.layers.Dense(8, activation="softmax")
])

# %%
#Using optimized learning rate: 
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(learning_rate=alpha),
              metrics=["accuracy"])

# %%
run_index = 1 # increment this at every run
run_logdir = os.path.join(os.curdir, "livertypes_logs", "run_{:03d}".format(run_index))
run_logdir
# Out:
# '.\\livertypes_logs\\run_001'

# %%
early_stopping_cb = keras.callbacks.EarlyStopping(
    min_delta=0.0005, # minimium amount of change to count as an improvement
    patience=20, # how many epochs to wait before stopping
)
checkpoint_cb = keras.callbacks.ModelCheckpoint("livertypes_model.h5", save_best_only=True)
tensorboard_cb = keras.callbacks.TensorBoard(run_logdir)

history = model.fit(X_train, y_train, epochs=200,
                    validation_data=(X_test, y_test),
                    callbacks=[checkpoint_cb, early_stopping_cb, tensorboard_cb])
# Out:
# Epoch 1/200
# 7/7 [==============================] - 3s 173ms/step - loss: 4.4152 - accuracy: 0.2311 - val_loss: 2.6102 - val_accuracy: 0.3696
# Epoch 2/200
# 7/7 [==============================] - 0s 64ms/step - loss: 1.7054 - accuracy: 0.3868 - val_loss: 1.8390 - val_accuracy: 0.4783
# Epoch 3/200
# 7/7 [==============================] - 0s 41ms/step - loss: 1.2903 - accuracy: 0.4858 - val_loss: 1.6085 - val_accuracy: 0.5109
# Epoch 4/200
# 7/7 [==============================] - 0s 57ms/step - loss: 1.1066 - accuracy: 0.5283 - val_loss: 1.4068 - val_accuracy: 0.4891
# Epoch 5/200
# 7/7 [==============================] - 0s 49ms/step - loss: 1.0325 - accuracy: 0.5425 - val_loss: 1.3997 - val_accuracy: 0.5109
# Epoch 6/200
# 7/7 [==============================] - 0s 49ms/step - loss: 0.9232 - accuracy: 0.5849 - val_loss: 1.2293 - val_accuracy: 0.5543
# Epoch 7/200
# 7/7 [==============================] - 0s 63ms/step - loss: 0.8717 - accuracy: 0.5896 - val_loss: 1.1266 - val_accuracy: 0.5435
# Epoch 8/200
# 7/7 [==============================] - 0s 51ms/step - loss: 0.7984 - accuracy: 0.5755 - val_loss: 1.1242 - val_accuracy: 0.5870
# Epoch 9/200
# 7/7 [==============================] - 0s 47ms/step - loss: 0.7585 - accuracy: 0.5755 - val_loss: 1.0816 - val_accuracy: 0.5870
# Epoch 10/200
# 7/7 [==============================] - 0s 67ms/step - loss: 0.7780 - accuracy: 0.5849 - val_loss: 1.1654 - val_accuracy: 0.5543
# Epoch 11/200
# 7/7 [==============================] - 0s 43ms/step - loss: 0.6911 - accuracy: 0.6557 - val_loss: 0.9641 - val_accuracy: 0.6739
# Epoch 12/200
# 7/7 [==============================] - 0s 44ms/step - loss: 0.6520 - accuracy: 0.6509 - val_loss: 1.0059 - val_accuracy: 0.5870
# Epoch 13/200
# 7/7 [==============================] - 0s 52ms/step - loss: 0.6400 - accuracy: 0.6792 - val_loss: 0.9687 - val_accuracy: 0.6413
# Epoch 14/200
# 7/7 [==============================] - 0s 46ms/step - loss: 0.6901 - accuracy: 0.6745 - val_loss: 0.9569 - val_accuracy: 0.6196
# Epoch 15/200
# 7/7 [==============================] - 0s 43ms/step - loss: 0.6186 - accuracy: 0.7028 - val_loss: 0.9263 - val_accuracy: 0.6087
# Epoch 16/200
# 7/7 [==============================] - 0s 31ms/step - loss: 0.6051 - accuracy: 0.7264 - val_loss: 0.9084 - val_accuracy: 0.6522
# Epoch 17/200
# 7/7 [==============================] - 0s 53ms/step - loss: 0.6019 - accuracy: 0.6981 - val_loss: 0.8874 - val_accuracy: 0.6522
# Epoch 18/200
# 7/7 [==============================] - 0s 60ms/step - loss: 0.6419 - accuracy: 0.7075 - val_loss: 0.8741 - val_accuracy: 0.6630
# Epoch 19/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.6261 - accuracy: 0.7311 - val_loss: 0.9043 - val_accuracy: 0.6413
# Epoch 20/200
# 7/7 [==============================] - 0s 41ms/step - loss: 0.5936 - accuracy: 0.7075 - val_loss: 0.8340 - val_accuracy: 0.7174
# Epoch 21/200
# 7/7 [==============================] - 0s 34ms/step - loss: 0.5345 - accuracy: 0.7594 - val_loss: 0.8462 - val_accuracy: 0.6304
# Epoch 22/200
# 7/7 [==============================] - 0s 45ms/step - loss: 0.5454 - accuracy: 0.7736 - val_loss: 0.8311 - val_accuracy: 0.7174
# Epoch 23/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.5890 - accuracy: 0.7311 - val_loss: 0.8062 - val_accuracy: 0.7500
# Epoch 24/200
# 7/7 [==============================] - 0s 25ms/step - loss: 0.5055 - accuracy: 0.7925 - val_loss: 0.8326 - val_accuracy: 0.7065
# Epoch 25/200
# 7/7 [==============================] - 0s 52ms/step - loss: 0.5465 - accuracy: 0.8113 - val_loss: 0.8289 - val_accuracy: 0.6413
# Epoch 26/200
# 7/7 [==============================] - 0s 36ms/step - loss: 0.6415 - accuracy: 0.7736 - val_loss: 0.8068 - val_accuracy: 0.7065
# Epoch 27/200
# 7/7 [==============================] - 1s 93ms/step - loss: 0.5274 - accuracy: 0.7925 - val_loss: 0.9349 - val_accuracy: 0.5870
# Epoch 28/200
# 7/7 [==============================] - 0s 17ms/step - loss: 0.5937 - accuracy: 0.7547 - val_loss: 0.8416 - val_accuracy: 0.6848
# Epoch 29/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.4956 - accuracy: 0.8066 - val_loss: 0.7980 - val_accuracy: 0.6957
# Epoch 30/200
# 7/7 [==============================] - 0s 16ms/step - loss: 0.5197 - accuracy: 0.8019 - val_loss: 1.0149 - val_accuracy: 0.5761
# Epoch 31/200
# 7/7 [==============================] - 0s 17ms/step - loss: 0.5203 - accuracy: 0.7877 - val_loss: 0.8166 - val_accuracy: 0.6739
# Epoch 32/200
# 7/7 [==============================] - 0s 16ms/step - loss: 0.4845 - accuracy: 0.8302 - val_loss: 0.8153 - val_accuracy: 0.6630
# Epoch 33/200
# 7/7 [==============================] - 0s 24ms/step - loss: 0.4776 - accuracy: 0.8491 - val_loss: 0.7597 - val_accuracy: 0.7391
# Epoch 34/200
# 7/7 [==============================] - 0s 19ms/step - loss: 0.4678 - accuracy: 0.8255 - val_loss: 0.7427 - val_accuracy: 0.7065
# Epoch 35/200
# 7/7 [==============================] - 0s 25ms/step - loss: 0.4555 - accuracy: 0.8491 - val_loss: 0.7884 - val_accuracy: 0.6848
# Epoch 36/200
# 7/7 [==============================] - 0s 17ms/step - loss: 0.4693 - accuracy: 0.8443 - val_loss: 0.7615 - val_accuracy: 0.6957
# Epoch 37/200
# 7/7 [==============================] - 0s 19ms/step - loss: 0.5086 - accuracy: 0.7830 - val_loss: 0.7215 - val_accuracy: 0.7826
# Epoch 38/200
# 7/7 [==============================] - 0s 18ms/step - loss: 0.4314 - accuracy: 0.8491 - val_loss: 0.8156 - val_accuracy: 0.6739
# Epoch 39/200
# 7/7 [==============================] - 0s 16ms/step - loss: 0.4490 - accuracy: 0.8302 - val_loss: 0.7302 - val_accuracy: 0.7174
# Epoch 40/200
# 7/7 [==============================] - 0s 20ms/step - loss: 0.4436 - accuracy: 0.8538 - val_loss: 0.8083 - val_accuracy: 0.6848
# Epoch 41/200
# 7/7 [==============================] - 0s 36ms/step - loss: 0.4291 - accuracy: 0.8538 - val_loss: 0.7067 - val_accuracy: 0.7609
# Epoch 42/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.4078 - accuracy: 0.8821 - val_loss: 0.7546 - val_accuracy: 0.7283
# Epoch 43/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.4100 - accuracy: 0.8679 - val_loss: 0.8043 - val_accuracy: 0.6304
# Epoch 44/200
# 7/7 [==============================] - 0s 24ms/step - loss: 0.4387 - accuracy: 0.8302 - val_loss: 0.7569 - val_accuracy: 0.6957
# Epoch 45/200
# 7/7 [==============================] - 0s 19ms/step - loss: 0.3920 - accuracy: 0.8915 - val_loss: 0.7168 - val_accuracy: 0.7283
# Epoch 46/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.4192 - accuracy: 0.8443 - val_loss: 0.7024 - val_accuracy: 0.7283
# Epoch 47/200
# 7/7 [==============================] - 0s 19ms/step - loss: 0.4349 - accuracy: 0.8491 - val_loss: 0.6933 - val_accuracy: 0.7283
# Epoch 48/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.3983 - accuracy: 0.8632 - val_loss: 0.6951 - val_accuracy: 0.7283
# Epoch 49/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.4054 - accuracy: 0.8491 - val_loss: 0.7339 - val_accuracy: 0.7283
# Epoch 50/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.4002 - accuracy: 0.8915 - val_loss: 0.6912 - val_accuracy: 0.7174
# Epoch 51/200
# 7/7 [==============================] - 0s 25ms/step - loss: 0.4358 - accuracy: 0.8208 - val_loss: 0.7388 - val_accuracy: 0.7065
# Epoch 52/200
# 7/7 [==============================] - 0s 24ms/step - loss: 0.3969 - accuracy: 0.8491 - val_loss: 0.7192 - val_accuracy: 0.7065
# Epoch 53/200
# 7/7 [==============================] - 0s 24ms/step - loss: 0.4279 - accuracy: 0.8396 - val_loss: 0.6745 - val_accuracy: 0.7717
# Epoch 54/200
# 7/7 [==============================] - 0s 18ms/step - loss: 0.3904 - accuracy: 0.8774 - val_loss: 0.9005 - val_accuracy: 0.6630
# Epoch 55/200
# 7/7 [==============================] - 0s 19ms/step - loss: 0.4420 - accuracy: 0.8538 - val_loss: 0.6750 - val_accuracy: 0.7500
# Epoch 56/200
# 7/7 [==============================] - 0s 25ms/step - loss: 0.3887 - accuracy: 0.8585 - val_loss: 0.7042 - val_accuracy: 0.7717
# Epoch 57/200
# 7/7 [==============================] - 0s 19ms/step - loss: 0.3695 - accuracy: 0.8632 - val_loss: 0.7048 - val_accuracy: 0.7609
# Epoch 58/200
# 7/7 [==============================] - 0s 16ms/step - loss: 0.3819 - accuracy: 0.8585 - val_loss: 0.6883 - val_accuracy: 0.7500
# Epoch 59/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.3581 - accuracy: 0.8962 - val_loss: 0.6743 - val_accuracy: 0.7283
# Epoch 60/200
# 7/7 [==============================] - 0s 17ms/step - loss: 0.4115 - accuracy: 0.8443 - val_loss: 0.7046 - val_accuracy: 0.7500
# Epoch 61/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.3727 - accuracy: 0.8491 - val_loss: 0.6601 - val_accuracy: 0.7391
# Epoch 62/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.3597 - accuracy: 0.8679 - val_loss: 0.6540 - val_accuracy: 0.7826
# Epoch 63/200
# 7/7 [==============================] - 0s 16ms/step - loss: 0.3719 - accuracy: 0.8726 - val_loss: 0.7351 - val_accuracy: 0.7500
# Epoch 64/200
# 7/7 [==============================] - 0s 17ms/step - loss: 0.4017 - accuracy: 0.8396 - val_loss: 0.7625 - val_accuracy: 0.6630
# Epoch 65/200
# 7/7 [==============================] - 0s 20ms/step - loss: 0.4036 - accuracy: 0.8302 - val_loss: 0.6548 - val_accuracy: 0.7283
# Epoch 66/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.3612 - accuracy: 0.8443 - val_loss: 0.6444 - val_accuracy: 0.7826
# Epoch 67/200
# 7/7 [==============================] - 0s 18ms/step - loss: 0.3466 - accuracy: 0.8774 - val_loss: 0.6622 - val_accuracy: 0.7391
# Epoch 68/200
# 7/7 [==============================] - 0s 16ms/step - loss: 0.3749 - accuracy: 0.8632 - val_loss: 0.6490 - val_accuracy: 0.7500
# Epoch 69/200
# 7/7 [==============================] - 0s 15ms/step - loss: 0.3611 - accuracy: 0.8538 - val_loss: 0.6491 - val_accuracy: 0.7717
# Epoch 70/200
# 7/7 [==============================] - 0s 14ms/step - loss: 0.3382 - accuracy: 0.8915 - val_loss: 0.6491 - val_accuracy: 0.7935
# Epoch 71/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.3941 - accuracy: 0.8491 - val_loss: 0.6444 - val_accuracy: 0.7826
# Epoch 72/200
# 7/7 [==============================] - 0s 16ms/step - loss: 0.3551 - accuracy: 0.8726 - val_loss: 0.7274 - val_accuracy: 0.6848
# Epoch 73/200
# 7/7 [==============================] - 0s 17ms/step - loss: 0.3378 - accuracy: 0.8774 - val_loss: 0.6959 - val_accuracy: 0.7174
# Epoch 74/200
# 7/7 [==============================] - 0s 15ms/step - loss: 0.3894 - accuracy: 0.8160 - val_loss: 0.6565 - val_accuracy: 0.7391
# Epoch 75/200
# 7/7 [==============================] - 0s 17ms/step - loss: 0.3519 - accuracy: 0.8915 - val_loss: 0.6766 - val_accuracy: 0.7717
# Epoch 76/200
# 7/7 [==============================] - 0s 17ms/step - loss: 0.3473 - accuracy: 0.8585 - val_loss: 0.9817 - val_accuracy: 0.5978
# Epoch 77/200
# 7/7 [==============================] - 0s 20ms/step - loss: 0.4032 - accuracy: 0.8491 - val_loss: 0.6313 - val_accuracy: 0.7935
# Epoch 78/200
# 7/7 [==============================] - 0s 15ms/step - loss: 0.3254 - accuracy: 0.9057 - val_loss: 0.6445 - val_accuracy: 0.7717
# Epoch 79/200
# 7/7 [==============================] - 0s 18ms/step - loss: 0.3256 - accuracy: 0.8821 - val_loss: 0.6275 - val_accuracy: 0.7609
# Epoch 80/200
# 7/7 [==============================] - 0s 14ms/step - loss: 0.3350 - accuracy: 0.8679 - val_loss: 0.6297 - val_accuracy: 0.7717
# Epoch 81/200
# 7/7 [==============================] - 0s 17ms/step - loss: 0.3199 - accuracy: 0.8962 - val_loss: 0.8009 - val_accuracy: 0.6739
# Epoch 82/200
# 7/7 [==============================] - 0s 16ms/step - loss: 0.3623 - accuracy: 0.8726 - val_loss: 0.6412 - val_accuracy: 0.7500
# Epoch 83/200
# 7/7 [==============================] - 0s 15ms/step - loss: 0.3105 - accuracy: 0.8915 - val_loss: 0.6897 - val_accuracy: 0.7391
# Epoch 84/200
# 7/7 [==============================] - 0s 15ms/step - loss: 0.3216 - accuracy: 0.8868 - val_loss: 0.6288 - val_accuracy: 0.7935
# Epoch 85/200
# 7/7 [==============================] - 0s 16ms/step - loss: 0.3232 - accuracy: 0.8868 - val_loss: 0.6399 - val_accuracy: 0.7500
# Epoch 86/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.3169 - accuracy: 0.8821 - val_loss: 0.6248 - val_accuracy: 0.7935
# Epoch 87/200
# 7/7 [==============================] - 0s 16ms/step - loss: 0.3060 - accuracy: 0.9009 - val_loss: 0.6294 - val_accuracy: 0.7717
# Epoch 88/200
# 7/7 [==============================] - 0s 15ms/step - loss: 0.3097 - accuracy: 0.9057 - val_loss: 0.6687 - val_accuracy: 0.7283
# Epoch 89/200
# 7/7 [==============================] - 0s 14ms/step - loss: 0.3292 - accuracy: 0.8774 - val_loss: 0.6964 - val_accuracy: 0.7065
# Epoch 90/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.3351 - accuracy: 0.8868 - val_loss: 0.6229 - val_accuracy: 0.7826
# Epoch 91/200
# 7/7 [==============================] - 0s 18ms/step - loss: 0.2928 - accuracy: 0.9057 - val_loss: 0.6316 - val_accuracy: 0.7717
# Epoch 92/200
# 7/7 [==============================] - 0s 18ms/step - loss: 0.3251 - accuracy: 0.8632 - val_loss: 0.6316 - val_accuracy: 0.7717
# Epoch 93/200
# 7/7 [==============================] - 0s 16ms/step - loss: 0.3160 - accuracy: 0.8821 - val_loss: 0.6890 - val_accuracy: 0.7391
# Epoch 94/200
# 7/7 [==============================] - 0s 20ms/step - loss: 0.3235 - accuracy: 0.8632 - val_loss: 0.6467 - val_accuracy: 0.7500
# Epoch 95/200
# 7/7 [==============================] - 0s 20ms/step - loss: 0.3177 - accuracy: 0.8962 - val_loss: 0.6362 - val_accuracy: 0.7717
# Epoch 96/200
# 7/7 [==============================] - 0s 20ms/step - loss: 0.3425 - accuracy: 0.8302 - val_loss: 0.6209 - val_accuracy: 0.7717
# Epoch 97/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.3212 - accuracy: 0.8679 - val_loss: 0.6170 - val_accuracy: 0.7826
# Epoch 98/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.2997 - accuracy: 0.9104 - val_loss: 0.6738 - val_accuracy: 0.7935
# Epoch 99/200
# 7/7 [==============================] - 0s 17ms/step - loss: 0.3206 - accuracy: 0.8632 - val_loss: 0.6479 - val_accuracy: 0.7717
# Epoch 100/200
# 7/7 [==============================] - 0s 25ms/step - loss: 0.2931 - accuracy: 0.9057 - val_loss: 0.6110 - val_accuracy: 0.7935
# Epoch 101/200
# 7/7 [==============================] - 0s 14ms/step - loss: 0.2812 - accuracy: 0.9292 - val_loss: 0.6394 - val_accuracy: 0.7609
# Epoch 102/200
# 7/7 [==============================] - 0s 15ms/step - loss: 0.3349 - accuracy: 0.8538 - val_loss: 0.7942 - val_accuracy: 0.6522
# Epoch 103/200
# 7/7 [==============================] - 0s 16ms/step - loss: 0.3309 - accuracy: 0.8632 - val_loss: 0.6311 - val_accuracy: 0.7717
# Epoch 104/200
# 7/7 [==============================] - 0s 16ms/step - loss: 0.3203 - accuracy: 0.8679 - val_loss: 0.6213 - val_accuracy: 0.7935
# Epoch 105/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.3128 - accuracy: 0.9057 - val_loss: 0.6105 - val_accuracy: 0.8152
# Epoch 106/200
# 7/7 [==============================] - 0s 16ms/step - loss: 0.3279 - accuracy: 0.8538 - val_loss: 0.6346 - val_accuracy: 0.7826
# Epoch 107/200
# 7/7 [==============================] - 0s 14ms/step - loss: 0.3464 - accuracy: 0.8726 - val_loss: 0.6536 - val_accuracy: 0.7935
# Epoch 108/200
# 7/7 [==============================] - 0s 15ms/step - loss: 0.3447 - accuracy: 0.8585 - val_loss: 0.6360 - val_accuracy: 0.8152
# Epoch 109/200
# 7/7 [==============================] - 0s 19ms/step - loss: 0.2912 - accuracy: 0.9057 - val_loss: 0.6080 - val_accuracy: 0.8152
# Epoch 110/200
# 7/7 [==============================] - 0s 17ms/step - loss: 0.2946 - accuracy: 0.8962 - val_loss: 0.6263 - val_accuracy: 0.7717
# Epoch 111/200
# 7/7 [==============================] - 0s 15ms/step - loss: 0.2802 - accuracy: 0.9104 - val_loss: 0.6153 - val_accuracy: 0.7935
# Epoch 112/200
# 7/7 [==============================] - 0s 14ms/step - loss: 0.2758 - accuracy: 0.9151 - val_loss: 0.6119 - val_accuracy: 0.7717
# Epoch 113/200
# 7/7 [==============================] - 0s 16ms/step - loss: 0.3106 - accuracy: 0.8774 - val_loss: 0.7022 - val_accuracy: 0.7391
# Epoch 114/200
# 7/7 [==============================] - 0s 12ms/step - loss: 0.3521 - accuracy: 0.8585 - val_loss: 0.7681 - val_accuracy: 0.7174
# Epoch 115/200
# 7/7 [==============================] - 0s 12ms/step - loss: 0.3288 - accuracy: 0.8632 - val_loss: 0.6291 - val_accuracy: 0.7826
# Epoch 116/200
# 7/7 [==============================] - 0s 13ms/step - loss: 0.2747 - accuracy: 0.9198 - val_loss: 0.6082 - val_accuracy: 0.7935
# Epoch 117/200
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2745 - accuracy: 0.8915 - val_loss: 0.6307 - val_accuracy: 0.7717
# Epoch 118/200
# 7/7 [==============================] - 0s 15ms/step - loss: 0.2725 - accuracy: 0.9104 - val_loss: 0.6114 - val_accuracy: 0.8478
# Epoch 119/200
# 7/7 [==============================] - 0s 15ms/step - loss: 0.2887 - accuracy: 0.9245 - val_loss: 0.6125 - val_accuracy: 0.7935
# Epoch 120/200
# 7/7 [==============================] - 0s 15ms/step - loss: 0.3054 - accuracy: 0.8726 - val_loss: 0.6287 - val_accuracy: 0.8043
# Epoch 121/200
# 7/7 [==============================] - 0s 19ms/step - loss: 0.2686 - accuracy: 0.9292 - val_loss: 0.6465 - val_accuracy: 0.7826
# Epoch 122/200
# 7/7 [==============================] - 0s 15ms/step - loss: 0.3044 - accuracy: 0.8915 - val_loss: 0.6269 - val_accuracy: 0.7826
# Epoch 123/200
# 7/7 [==============================] - 0s 13ms/step - loss: 0.2780 - accuracy: 0.8962 - val_loss: 0.6298 - val_accuracy: 0.7609
# Epoch 124/200
# 7/7 [==============================] - 0s 15ms/step - loss: 0.2683 - accuracy: 0.9198 - val_loss: 0.6186 - val_accuracy: 0.7826
# Epoch 125/200
# 7/7 [==============================] - 0s 14ms/step - loss: 0.3165 - accuracy: 0.8821 - val_loss: 0.6440 - val_accuracy: 0.7609
# Epoch 126/200
# 7/7 [==============================] - 0s 15ms/step - loss: 0.2913 - accuracy: 0.8868 - val_loss: 0.6162 - val_accuracy: 0.8152
# Epoch 127/200
# 7/7 [==============================] - 0s 15ms/step - loss: 0.2620 - accuracy: 0.9057 - val_loss: 0.6236 - val_accuracy: 0.7826
# Epoch 128/200
# 7/7 [==============================] - 0s 15ms/step - loss: 0.2569 - accuracy: 0.9009 - val_loss: 0.6630 - val_accuracy: 0.7826
# Epoch 129/200
# 7/7 [==============================] - 0s 16ms/step - loss: 0.2760 - accuracy: 0.9151 - val_loss: 0.6549 - val_accuracy: 0.8261

# %%
model = keras.models.load_model("livertypes_model.h5") # rollback to best model
model.evaluate(X_test, y_test)
model.evaluate(X_train, y_train)
# Out:
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6080 - accuracy: 0.8152
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2693 - accuracy: 0.9245
# [0.26927241683006287, 0.9245283007621765]

# %%
#Plot of Loss, Val_Loss, Accuracy and Val_Accuracy, with loss and val_loss normalized by max and min
hist = pd.DataFrame(history.history)#.plot(figsize=(8, 5))
hist['loss'] = (hist['loss'] - hist['loss'].min()) / (hist['loss'].max() - hist['loss'].min())
hist['val_loss'] = (hist['val_loss'] - hist['val_loss'].min()) / (hist['val_loss'].max() - hist['val_loss'].min())
hist.plot(figsize=(8,5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
 
plt.show()
