# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import sklearn.decomposition
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import auc, accuracy_score, confusion_matrix, roc_curve, precision_score, recall_score, f1_score
import tensorflow as tf
from tensorflow import keras
import os

# %%
MergedData0 = pd.read_csv('Data.csv', index_col=0);
MergedData1 = MergedData0.iloc[:, :-1]
y = pd.read_csv("cancer_kidney_training.txt", index_col='gene')
y.rename_axis("DepMap_ID")
y = y == 'positive'
data = MergedData1.merge(y, how='inner', left_index=True, right_index=True)
Data = data.iloc[:, :-1]
y = data.iloc[:, -1]
display(Data)
display(y)
# Out:
#          ACH-000001_x  ACH-000004_x  ACH-000005_x  ACH-000007_x  ACH-000009_x  \
# ACSL3        0.206118      0.564185      0.151348      0.126941      0.334351
# ACSL3        0.206118      0.564185      0.151348      0.126941      0.334351
# ADAD2        0.015341      0.057175      0.235037      0.044320      0.013512
# ADAMTS4      0.046855      0.256482      0.073674      0.154893      0.292487
# ADAMTS4      0.046855      0.256482      0.073674      0.154893      0.292487
# ...               ...           ...           ...           ...           ...
# ZBTB38       0.026336      0.054377      0.003372      0.023879      0.020726
# ZFP41        0.054813      0.038026      0.039214      0.231471      0.046033
# ZNF398       0.009591      0.007345      0.016498      0.076604      0.041353
# ZNF398       0.009591      0.007345      0.016498      0.076604      0.041353
# ZNF596       0.012495      0.017708      0.000853      0.151118      0.019963
#
#          ACH-000011_x  ACH-000012_x  ACH-000013_x  ACH-000014_x  ACH-000015_x  \
# ACSL3        0.056647      0.823666      0.068817      0.626790      0.960795
# ACSL3        0.056647      0.823666      0.068817      0.626790      0.960795
# ADAD2        0.035757      0.108234      0.120932      0.016063      0.006215
# ADAMTS4      0.110251      0.099467      0.137394      0.057690      0.041533
# ADAMTS4      0.110251      0.099467      0.137394      0.057690      0.041533
# ...               ...           ...           ...           ...           ...
# ZBTB38       0.020952      0.026529      0.025580      0.055892      0.010696
# ZFP41        0.090209      0.049339      0.052933      0.559185      0.004391
# ZNF398       0.012088      0.005942      0.004196      0.307829      0.027200
# ZNF398       0.012088      0.005942      0.004196      0.307829      0.027200
# ZNF596       0.026989      0.017625      0.009328      0.019788      0.088494
#
#          ...  ACH-001578  ACH-000036  ACH-000973  ACH-001128  ACH-000750  \
# ACSL3    ...    5.639232    5.617651    5.078097    5.674687    6.429783
# ACSL3    ...    5.639232    5.617651    5.078097    5.674687    6.429783
# ADAD2    ...    0.150560    0.000000    0.000000    0.000000    0.000000
# ADAMTS4  ...    0.226509    0.028569    0.014355    0.070389    0.000000
# ADAMTS4  ...    0.226509    0.028569    0.014355    0.070389    0.000000
# ...      ...         ...         ...         ...         ...         ...
# ZBTB38   ...    1.655352    3.804260    2.521051    4.301588    5.774524
# ZFP41    ...    2.625270    2.857981    3.543496    3.121015    3.572890
# ZNF398   ...    3.850999    2.657640    2.601697    2.548437    1.480265
# ZNF398   ...    3.850999    2.657640    2.601697    2.548437    1.480265
# ZNF596   ...    1.575312    3.023255    1.691534    2.819668    2.063503
#
#          ACH-000285  ACH-002669  ACH-001858  ACH-001997  ACH-000052
# ACSL3      4.640968    6.672284    6.075747    5.606442    6.079591
# ACSL3      4.640968    6.672284    6.075747    5.606442    6.079591
# ADAD2      0.310340    0.000000    0.000000    0.028569    0.014355
# ADAMTS4    0.028569    0.014355    0.000000    0.014355    2.462052
# ADAMTS4    0.028569    0.014355    0.000000    0.014355    2.462052
# ...             ...         ...         ...         ...         ...
# ZBTB38     2.592158    4.466627    4.904484    3.906891    3.428946
# ZFP41      3.882643    2.389567    2.304511    3.372952    3.951401
# ZNF398     3.995485    2.887525    2.137504    2.505891    3.129283
# ZNF398     3.995485    2.887525    2.137504    2.505891    3.129283
# ZNF596     1.992768    0.895303    0.263034    1.395063    2.711495
#
# [380 rows x 3578 columns]
# ACSL3      False
# ACSL3      False
# ADAD2      False
# ADAMTS4    False
# ADAMTS4    False
#            ...
# ZBTB38     False
# ZFP41      False
# ZNF398     False
# ZNF398     False
# ZNF596     False
# Name: label, Length: 380, dtype: bool

# %%
data_gene_dep = Data.iloc[:, 0:1086]
data_gene_dep;
data_gene_eff = Data.iloc[:, 1087:2172]
data_gene_eff;
data_express = Data.iloc[:, 2173:3578]
data_express;

# %%
pca = sklearn.decomposition.PCA(n_components=8, svd_solver='randomized')
X1 = pca.fit_transform(data_gene_dep)
print(pca.explained_variance_ratio_)
# Out:
# [0.81608122 0.01373532 0.0123943  0.01032878 0.00855543 0.00821923
#  0.00657963 0.00613097]

# %%
pca = sklearn.decomposition.PCA(n_components=8, svd_solver='randomized')
X2 = pca.fit_transform(data_gene_eff)
print(pca.explained_variance_ratio_)
# Out:
# [0.85505006 0.01136764 0.00873795 0.00705049 0.00581364 0.00507887
#  0.00502109 0.00447377]

# %%
pca = sklearn.decomposition.PCA(n_components=8, svd_solver='randomized')
X3 = pca.fit_transform(data_express)
print(pca.explained_variance_ratio_)
# Out:
# [0.7993859  0.02808854 0.02400717 0.01234759 0.00777898 0.00669571
#  0.00616573 0.00526232]

# %%
X4 = np.concatenate((X1, X2, X3), axis=1)
print(X4.shape)
# Out:
# (380, 24)

# %%
select = np.maximum(y, np.random.rand(len(y)) < sum(y)/(len(y) - sum(y)))
X4 = X4[select]
y = y[select]
print(X4.shape)
print(y.shape)
print(sum(y))
sns.scatterplot(x= X4[:,0], y=X4[:,1], hue=y)
plt.show()
# Out:
# (229, 24)
# (229,)
# 112

# %%
# Get the training and test data
X_train, X_test, y_train, y_test = train_test_split(X4, y, test_size=0.3)

# Fit the model
model = LogisticRegression(max_iter=10000).fit(X_train, y_train)

y_pred = model.predict(X_test)
y_pred_rt = model.predict_proba(X_test)[:, 1]

accuracy = str(accuracy_score(y_test, y_pred))
fpr, tpr, thresholds = roc_curve(y_test, y_pred_rt)
auc_value = str(auc(fpr, tpr))
precision = str(precision_score(y_test, y_pred))
recall = str(recall_score(y_test, y_pred))
f1score = str(f1_score(y_test, y_pred, average="weighted"))

# %%
print("Accuracy:" + accuracy)
print("Precision:" + precision)
print("Recall:" + recall)

conf_mx = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_mx)
plt.show()

print(conf_mx)
# Out:
# Accuracy:0.782608695652174
# Precision:0.7272727272727273
# Recall:0.8
# [[30  9]
#  [ 6 24]]

# %%
keras.backend.clear_session()
np.random.seed(50)
tf.random.set_seed(50)

# %%
K = keras.backend

class ExponentialLearningRate(keras.callbacks.Callback):
    def __init__(self, factor):
        self.factor = factor
        self.rates = []
        self.losses = []
    def on_batch_end(self, batch, logs):
        self.rates.append(K.get_value(self.model.optimizer.lr))
        self.losses.append(logs["loss"])
        K.set_value(self.model.optimizer.lr, self.model.optimizer.lr * self.factor)

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[24]),
    keras.layers.Dense(150, activation="relu"),
    keras.layers.Dense(75, activation="relu"),
    keras.layers.Dense(8, activation="softmax")
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 24)                0
#
#  dense (Dense)               (None, 150)               3750
#
#  dense_1 (Dense)             (None, 75)                11325
#
#  dense_2 (Dense)             (None, 8)                 608
#
# =================================================================
# Total params: 15,683
# Trainable params: 15,683
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(learning_rate=1e-3),
              metrics=["accuracy"])
expon_lr = ExponentialLearningRate(factor=1.005)

# %%
history = model.fit(X_train, y_train, epochs=5,
                    validation_data=(X_test, y_test),
                    callbacks=[expon_lr])
# Out:
# Epoch 1/5
# 5/5 [==============================] - 1s 92ms/step - loss: 4.7233 - accuracy: 0.3000 - val_loss: 2.1334 - val_accuracy: 0.4058
# Epoch 2/5
# 5/5 [==============================] - 0s 15ms/step - loss: 1.7288 - accuracy: 0.4812 - val_loss: 1.8204 - val_accuracy: 0.4348
# Epoch 3/5
# 5/5 [==============================] - 0s 21ms/step - loss: 1.7268 - accuracy: 0.4375 - val_loss: 1.5393 - val_accuracy: 0.4493
# Epoch 4/5
# 5/5 [==============================] - 0s 20ms/step - loss: 1.4847 - accuracy: 0.5125 - val_loss: 1.2767 - val_accuracy: 0.4493
# Epoch 5/5
# 5/5 [==============================] - 0s 19ms/step - loss: 1.2346 - accuracy: 0.5375 - val_loss: 1.4380 - val_accuracy: 0.4928

# %%
plt.plot(expon_lr.rates, expon_lr.losses)
plt.gca().set_xscale('log')
plt.hlines(min(expon_lr.losses), min(expon_lr.rates), max(expon_lr.rates))
plt.axis([min(expon_lr.rates), max(expon_lr.rates), 0, expon_lr.losses[0]])
plt.grid()
plt.xlabel("Learning rate")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')

# %%
print("Min Loss: " + str(min(expon_lr.losses)))
print("Best learning rate: " + str(expon_lr.rates[np.argmin(expon_lr.losses)]))
alpha = expon_lr.rates[np.argmin(expon_lr.losses)];
# Out:
# Min Loss: 1.2195990085601807
# Best learning rate: 0.0011048956

# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import layers, callbacks
keras.backend.clear_session()
np.random.seed(50)
tf.random.set_seed(50)

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[24]),
    keras.layers.Dense(150, activation="relu"),
    keras.layers.Dense(75, activation="relu"),
    keras.layers.Dense(8, activation="softmax")
])

# %%
#Using optimized learning rate: 
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(learning_rate=alpha),
              metrics=["accuracy"])

# %%
run_index = 1 # increment this at every run
run_logdir = os.path.join(os.curdir, "kidneytypes_logs", "run_{:03d}".format(run_index))
run_logdir
# Out:
# '.\\kidneytypes_logs\\run_001'

# %%
early_stopping_cb = keras.callbacks.EarlyStopping(
    min_delta=0.0005, # minimium amount of change to count as an improvement
    patience=20, # how many epochs to wait before stopping
)
checkpoint_cb = keras.callbacks.ModelCheckpoint("kidneytypes_model.h5", save_best_only=True)
tensorboard_cb = keras.callbacks.TensorBoard(run_logdir)

history = model.fit(X_train, y_train, epochs=200,
                    validation_data=(X_test, y_test),
                    callbacks=[checkpoint_cb, early_stopping_cb, tensorboard_cb])
# Out:
# Epoch 1/200
# 5/5 [==============================] - 2s 137ms/step - loss: 3.0012 - accuracy: 0.3812 - val_loss: 2.2493 - val_accuracy: 0.4348
# Epoch 2/200
# 5/5 [==============================] - 0s 79ms/step - loss: 1.5606 - accuracy: 0.5125 - val_loss: 1.9484 - val_accuracy: 0.4493
# Epoch 3/200
# 5/5 [==============================] - 0s 58ms/step - loss: 1.6793 - accuracy: 0.4938 - val_loss: 1.7448 - val_accuracy: 0.4928
# Epoch 4/200
# 5/5 [==============================] - 0s 62ms/step - loss: 1.5211 - accuracy: 0.5375 - val_loss: 1.7654 - val_accuracy: 0.4928
# Epoch 5/200
# 5/5 [==============================] - 0s 92ms/step - loss: 1.3325 - accuracy: 0.5562 - val_loss: 1.7856 - val_accuracy: 0.4928
# Epoch 6/200
# 5/5 [==============================] - 0s 76ms/step - loss: 1.7103 - accuracy: 0.4875 - val_loss: 1.5108 - val_accuracy: 0.4928
# Epoch 7/200
# 5/5 [==============================] - 0s 122ms/step - loss: 1.0432 - accuracy: 0.6125 - val_loss: 1.3711 - val_accuracy: 0.4928
200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.2659 - accuracy: 0.9187 - val_loss: 0.4420 - val_accuracy: 0.7681
# Epoch 176/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.3108 - accuracy: 0.8687 - val_loss: 0.4538 - val_accuracy: 0.7391
# Epoch 177/200
# 5/5 [==============================] - 0s 20ms/step - loss: 0.2549 - accuracy: 0.9125 - val_loss: 0.4493 - val_accuracy: 0.8261
# Epoch 178/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2893 - accuracy: 0.8687 - val_loss: 0.4742 - val_accuracy: 0.7826
# Epoch 179/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.3515 - accuracy: 0.8500 - val_loss: 0.9955 - val_accuracy: 0.6232
# Epoch 180/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.3287 - accuracy: 0.8625 - val_loss: 0.4721 - val_accuracy: 0.8116
# Epoch 181/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.2611 - accuracy: 0.9250 - val_loss: 0.4403 - val_accuracy: 0.7971
# Epoch 182/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.3799 - accuracy: 0.8125 - val_loss: 0.4577 - val_accuracy: 0.8116
# Epoch 183/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.3297 - accuracy: 0.8500 - val_loss: 0.4884 - val_accuracy: 0.7391
# Epoch 184/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.3596 - accuracy: 0.8438 - val_loss: 0.4650 - val_accuracy: 0.7826
# Epoch 185/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.2475 - accuracy: 0.9187 - val_loss: 0.5216 - val_accuracy: 0.7101
# Epoch 186/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.2537 - accuracy: 0.9187 - val_loss: 0.4736 - val_accuracy: 0.7826
# Epoch 187/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2566 - accuracy: 0.9062 - val_loss: 0.4826 - val_accuracy: 0.7536
# Epoch 188/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.2543 - accuracy: 0.9125 - val_loss: 0.4545 - val_accuracy: 0.8261
# Epoch 189/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2374 - accuracy: 0.9375 - val_loss: 0.4477 - val_accuracy: 0.7391
# Epoch 190/200
# 5/5 [==============================] - 0s 28ms/step - loss: 0.2462 - accuracy: 0.9062 - val_loss: 0.4402 - val_accuracy: 0.8406
# Epoch 191/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2387 - accuracy: 0.9375 - val_loss: 0.4899 - val_accuracy: 0.7391
# Epoch 192/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.4569 - accuracy: 0.8188 - val_loss: 0.4602 - val_accuracy: 0.7826
# Epoch 193/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.2503 - accuracy: 0.9187 - val_loss: 0.4703 - val_accuracy: 0.7681
# Epoch 194/200
# 5/5 [==============================] - 0s 32ms/step - loss: 0.2421 - accuracy: 0.9125 - val_loss: 0.4309 - val_accuracy: 0.7971
# Epoch 195/200
# 5/5 [==============================] - 0s 20ms/step - loss: 0.2479 - accuracy: 0.9250 - val_loss: 0.4336 - val_accuracy: 0.8116
# Epoch 196/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.4009 - accuracy: 0.8188 - val_loss: 0.4424 - val_accuracy: 0.7826
# Epoch 197/200
# 5/5 [==============================] - 0s 34ms/step - loss: 0.2519 - accuracy: 0.8813 - val_loss: 0.4296 - val_accuracy: 0.8261
# Epoch 198/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3874 - accuracy: 0.8250 - val_loss: 0.9275 - val_accuracy: 0.6087
# Epoch 199/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3982 - accuracy: 0.8125 - val_loss: 0.5280 - val_accuracy: 0.7681
# Epoch 200/200
# 5/5 [==============================] - 0s 24ms/step - loss: 0.2414 - accuracy: 0.9250 - val_loss: 0.4341 - val_accuracy: 0.8261

# %%
model = keras.models.load_model("kidneytypes_model.h5") # rollback to best model
model.evaluate(X_test, y_test)
model.evaluate(X_train, y_train)
# Out:
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4296 - accuracy: 0.8261
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2341 - accuracy: 0.9187
# [0.23409625887870789, 0.918749988079071]

# %%
#Plot of Loss, Val_Loss, Accuracy and Val_Accuracy, with loss and val_loss normalized by max and min
hist = pd.DataFrame(history.history)#.plot(figsize=(8, 5))
hist['loss'] = (hist['loss'] - hist['loss'].min()) / (hist['loss'].max() - hist['loss'].min())
hist['val_loss'] = (hist['val_loss'] - hist['val_loss'].min()) / (hist['val_loss'].max() - hist['val_loss'].min())
hist.plot(figsize=(8,5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
 
plt.show()
